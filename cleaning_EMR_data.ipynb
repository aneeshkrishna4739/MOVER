# %%
import polars as pl
import os
import pandas as pd
import json

# %%
def encode_column_and_replace(df, col_name,encoding_dict_=None):

    if encoding_dict_ is None:
        out = df.select(pl.col(col_name).unique()).with_row_count()
        out = out.select([col_name,'row_nr'])
        encoding_dict = dict(out.iter_rows())
    else:
        encoding_dict = encoding_dict_
    df = df.with_columns(pl.col(col_name).map_dict(encoding_dict,return_dtype=pl.UInt64).alias(col_name+'_encoded'))
    return df,encoding_dict

def encode_two_columns(df, col_1,col_2):
    encoding_dict = dict(df.select([col_1,col_2]).unique().iter_rows())
    return encoding_dict

# %% [markdown]
# # Cleaning patient history sample

# %%
patient_history_encoding = {}
cols_to_encode = ['dx_name']
data = pl.read_csv('EPIC_EMR/patient_history.csv',dtypes={'diagnosis_code':pl.Utf8})
data = data.unique()

# %%
data.shape
# Out:
# (437721, 3)

# %%
data.head()
# Out:
# shape: (5, 3)
# ┌──────────────────┬────────────────┬───────────────────────────────────┐
# │ mrn              ┆ diagnosis_code ┆ dx_name                           │
# │ ---              ┆ ---            ┆ ---                               │
# │ str              ┆ str            ┆ str                               │
# ╞══════════════════╪════════════════╪═══════════════════════════════════╡
# │ 0fef63bb63c4e4fb ┆ 218.0          ┆ Submucous leiomyoma of uterus     │
# │ 5a6b742b38dbc6c7 ┆ 218.0          ┆ Submucous leiomyoma of uterus     │
# │ 13e76a6d564f8049 ┆ 238.2          ┆ Neoplasm of uncertain behavior o… │
# │ e10847d0e11f7537 ┆ 238.2          ┆ Neoplasm of uncertain behavior o… │
# │ e9e71c10b4505288 ┆ 238.2          ┆ Neoplasm of uncertain behavior o… │
# └──────────────────┴────────────────┴───────────────────────────────────┘

# %%
patient_history_encoding['dx_name___diagnosis_code'] = encode_two_columns(data,'dx_name','diagnosis_code')
for col in cols_to_encode:
    data, patient_history_encoding[col] = encode_column_and_replace(data,col)

# %%
data.head()
# Out:
# shape: (5, 4)
# ┌──────────────────┬────────────────┬───────────────────────────────────┬─────────────────┐
# │ mrn              ┆ diagnosis_code ┆ dx_name                           ┆ dx_name_encoded │
# │ ---              ┆ ---            ┆ ---                               ┆ ---             │
# │ str              ┆ str            ┆ str                               ┆ u64             │
# ╞══════════════════╪════════════════╪═══════════════════════════════════╪═════════════════╡
# │ 0fef63bb63c4e4fb ┆ 218.0          ┆ Submucous leiomyoma of uterus     ┆ 47669           │
# │ 5a6b742b38dbc6c7 ┆ 218.0          ┆ Submucous leiomyoma of uterus     ┆ 47669           │
# │ 13e76a6d564f8049 ┆ 238.2          ┆ Neoplasm of uncertain behavior o… ┆ 11621           │
# │ e10847d0e11f7537 ┆ 238.2          ┆ Neoplasm of uncertain behavior o… ┆ 11621           │
# │ e9e71c10b4505288 ┆ 238.2          ┆ Neoplasm of uncertain behavior o… ┆ 11621           │
# └──────────────────┴────────────────┴───────────────────────────────────┴─────────────────┘

# %%
data.null_count()
# Out:
# shape: (1, 4)
# ┌─────┬────────────────┬─────────┬─────────────────┐
# │ mrn ┆ diagnosis_code ┆ dx_name ┆ dx_name_encoded │
# │ --- ┆ ---            ┆ ---     ┆ ---             │
# │ u32 ┆ u32            ┆ u32     ┆ u32             │
# ╞═════╪════════════════╪═════════╪═════════════════╡
# │ 0   ┆ 107424         ┆ 0       ┆ 0               │
# └─────┴────────────────┴─────────┴─────────────────┘

# %%
patient_history_encoding.keys()
# Out:
# dict_keys(['dx_name___diagnosis_code', 'dx_name'])

# %%
data = data.select([
    'mrn','dx_name_encoded'])
data.shape
# Out:
# (437721, 2)

# %%
data
# Out:
# shape: (437_721, 2)
# ┌──────────────────┬─────────────────┐
# │ mrn              ┆ dx_name_encoded │
# │ ---              ┆ ---             │
# │ str              ┆ u64             │
# ╞══════════════════╪═════════════════╡
# │ a75b440dac37861e ┆ 9815            │
# │ 562502ca0db7f00e ┆ 9815            │
# │ 2bfcf8009624887e ┆ 57567           │
# │ 86baf59d6a64fbcd ┆ 57567           │
# │ …                ┆ …               │
# │ 72aa50b6bc2691c0 ┆ 56868           │
# │ dd706baedd8ab9fa ┆ 2100            │
# │ 0208bec15f231550 ┆ 34193           │
# │ 56e0a837a9de5532 ┆ 34193           │
# └──────────────────┴─────────────────┘

# %%
data.write_csv('EPIC_EMR_cleaned/patient_history_cleaned.csv')

# %%
patient_history_encoding
# Out:
# {'dx_name___diagnosis_code': {'Acute maxillary sinusitis': '461.0',
#   'Mitral valve prolapse': '424.0',
#   'Nasal bone fx-closed': '802.0',
#   'Celiac disease': '579.0',
#   'Hydroureter': '593.5',
#   'Supraventricular tachycardia (CMS-HCC)': '427.89',
#   'Thrombophlebitis': '451.9',
#   'Septic arthritis (CMS-HCC)': '711.00',
#   'Meibomian gland disease': '374.89',
#   'Inguinal hernia': '550.90',
#   'Microprolactinoma (CMS-HCC)': '227.3',
#   'S/P left inguinal hernia repair': 'V45.89',
#   'Anemia due to antineoplastic chemotherapy': '285.3',
#   'CHF exacerbation (CMS-HCC)': '428.0',
#   'Bleeding duodenal ulcer': '532.40',
#   'Dialysis patient (CMS-HCC)': 'V45.11',
#   'Stem cells transplant status (CMS-HCC)': 'V42.82',
#   'Contracture of left knee': '718.46',
#   'Borborygmi': '787.5',
#   'Eye lesion': '379.90',
#   'Retained magnetic metal fragment': 'V90.11',
#   'Fibroadenoma of breast': '217',
#   'Acute hip pain': '719.45',
#   'Routine history and physical examination of adult': 'V70.0',
#   'Posterior dislocation of elbow, open, right, initial encounter': None,
#   'Dialysis AV fistula malfunction, initial encounter (CMS-HCC)': None,
#   'Amputation of right hand with complication, initial encounter (CMS-HCC)': None,
#   'Postoperative wound infection, initial encounter': None,
#   'Closed displaced intertrochanteric fracture of right femur, initial encounter (CMS-HCC)': None,
#   'Injury of right ankle, initial encounter': None,
#   'Problem with dialysis shunt (CMS-HCC)': None,
#   'Ganglion cyst of wrist, right': None,
#   'Coronary artery disease involving native coronary artery of native heart with unstable angina pectoris (CMS-HCC)': None,
#   'Fracture of multiple ribs of both sides': None,
#   'Other fatigue': None,
#   'Incontinence of feces with fecal urgency': None,
#   'Invasive ductal carcinoma of left breast, stage 2 (CMS-HCC)': None,
#   'Midline low back pain without sciatica, unspecified chronicity': None,
#   'Multiple closed fractures of pelvis with disruption of pelvic ring with delayed healing, subsequent encounter': None,
#   'Hematuria, unspecified type': None,
#   'Degenerative myopia with other maculopathy, bilateral eye': None,
#   'Groin ulcer (CMS-HCC)': None,
#   'Dysmenorrhea': '625.3',
#   'Ulcer': '707.9',
#   'Hoarseness': '784.42',
#   'Eczema': '692.9',
#   'Obstructive sleep apnea': '327.23',
#   'Nystagmus': '379.50',
#   'Right hip pain': '719.45',
#   'Colorectal cancer, stage IV (CMS-HCC)': '154.0',
#   'Basal cell carcinoma of forehead': '173.31',
#   'Severely displaced zone III fracture of sacrum (CMS-HCC)': '805.6',
#   'AKI (acute kidney injury) (CMS-HCC)': '584.9',
#   'UGI bleed': '578.9',
#   'Encounter for routine gynecological examination': 'V72.31',
#   'Ruptured aneurysm of thoracoabdominal aorta (CMS-HCC)': '441.6',
#   'Recurrent ventral incisional hernia': '553.21',
#   'Benign colon polyp': '211.3',
#   'Sacral radiculopathy': '724.4',
#   'Streptococcal bacteremia': '790.7',
#   'Closed left ankle fracture, sequela': None,
#   'Infection of spinal cord stimulator (CMS-HCC)': '996.63',
#   'Uncontrolled type 2 diabetes mellitus (CMS-HCC)': None,
#   'Retinal dialysis of left eye': None,
#   'Stress at work': 'V62.1',
#   'Atherosclerosis of native coronary artery of native heart without angina pectoris': None,
#   'Membranous urethral stricture': None,
#   'Nausea without vomiting': None,
#   'Osteoarthritis of lumbosacral spine with myelopathy': None,
#   'Laceration of right hand involving tendon, initial encounter': None,
#   'Cancer of left lung (CMS-HCC)': None,
#   'Acute hypoxemic respiratory failure (CMS-HCC)': None,
#   'Acute appendicitis with localized peritonitis, unspecified whether abscess present, unspecified whether gangrene present, unspecified whether perforation present': None,
#   'Nontoxic multinodular goiter': '241.1',
#   'Gastric artery injury': '902.21',
#   'Adhesive arachnoiditis': '322.9',
#   'Abdominal aneurysm, ruptured (CMS-HCC)': '441.3',
#   'Prostate cancer (CMS-HCC)': '185',
#   'Dysuria': '788.1',
#   'Personal history of breast cancer': 'V10.3',
#   'Tracheostomy in place (CMS-HCC)': 'V44.0',
#   'Aneurysm (CMS-HCC)': '442.9',
#   'Spinal stenosis': '724.00',
#   'Upper GI bleed': '578.9',
#   'Biliary obstruction': '576.2',
#   'Transplant': 'V42.9',
#   'Unilateral congenital absence of kidney': '753.0',
#   'Metabolic acidosis with respiratory acidosis': '276.4',
#   'Injury of left femoral artery': '904.1',
#   'Cavitary lesion of lung': '518.89',
#   'History of craniotomy': 'V45.89',
#   'Influenza vaccine needed': 'V04.81',
#   'Erythrocytosis': '289.0',
#   'History of lymphopenia': 'V12.3',
#   'Abnormal uterine bleeding': '626.9',
#   'Heterotopic ossification': '733.99',
#   'Open displaced fracture of distal phalanx of right index finger, initial encounter': None,
#   'Language barrier to communication': None,
#   'Accident caused by fireworks, subsequent encounter': None,
#   'Malignant melanoma of chest wall (CMS-HCC)': '172.5',
#   'Infection of breast implant, initial encounter (CMS-HCC)': None,
#   'Open displaced transverse fracture of shaft of left humerus, initial encounter': None,
#   'Multiple rib fractures involving four or more ribs': None,
#   'Longstanding persistent atrial fibrillation (CMS-HCC)': None,
#   'Cervical cancer, FIGO stage IVA (CMS-HCC)': None,
#   'Influenza vaccination declined by patient': None,
#   'Tendinitis of left infraspinatus tendon': None,
#   'Status post total left knee replacement': None,
#   'Trigger point': None,
#   'Squamous cell carcinoma of right ear': None,
#   'Gastrointestinal hemorrhage, unspecified gastrointestinal hemorrhage type': None,
#   'Small vessel vasculitis (CMS-HCC)': None,
#   'Pressure injury of other site, stage 2 (CMS-HCC)': None,
#   'Counseled about COVID-19 virus infection': None,
#   'Itching': '698.9',
#   'Respiratory insufficiency': '786.09',
#   'Pneumonia due to organism': '483.8',
#   'DKA (diabetic ketoacidoses) (CMS-HCC)': '250.10',
#   'Left-sided weakness': '728.87',
#   'Dyspnea': '786.09',
#   'Anemia, blood loss': '280.0',
#   'Difficulty sleeping': '780.50',
#   'Angina pectoris (CMS-HCC)': '413.9',
#   'Adynamic ileus (CMS-HCC)': '560.1',
#   'Gallstone': '574.20',
#   'Wet gangrene (CMS-HCC)': '785.4',
#   'Malignant neoplasm of cardia of stomach (CMS-HCC)': '151.0',
#   'SS (spinal stenosis)': '724.00',
#   'Acute pyelonephritis': '590.10',
#   'History of anemia': 'V12.3',
#   'MRSA bacteremia': '790.7',
#   'Obesity, Class I, BMI 30-34.9': '278.00',
#   'Abdominal pain, acute, right upper quadrant': '789.01',
#   'Organic psychosis': '294.9',
#   'Lower urinary tract symptoms (LUTS)': '788.99',
#   'Lentigines': '709.09',
#   'S/P cesarean section': 'V45.89',
#   'Borderline diabetic': '790.29',
#   'Right renal mass': '593.9',
#   'Bilateral occipital neuralgia': '723.8',
#   'Alcoholic intoxication with complication (CMS-HCC)': None,
#   'Pilon fracture of left tibia': None,
#   'Malignant neoplasm of right kidney (CMS-HCC)': None,
#   'Skin ulcer, limited to breakdown of skin (CMS-HCC)': None,
#   'Encounter for screening colonoscopy for non-high-risk patient': 'V76.51',
#   'Hypothyroidism affecting pregnancy, antepartum': None,
#   'Subjective tinnitus of both ears': None,
#   'Status post total right knee replacement': None,
#   'Gastrointestinal hemorrhage associated with acute gastritis': None,
#   'Olecranon fracture, right, closed, with delayed healing, subsequent encounter': None,
#   'Radiculopathy due to disorder of intervertebral disc of lumbar spine': None,
#   'Placenta previa in third trimester': None,
#   'Toxic maculopathy of both eyes due to hydroxychloroquine therapy': None,
#   'Medial tibial stress syndrome, left, initial encounter': None,
#   'S/P bilateral foot surgery': None,
#   'Osteoporosis of lumbar spine': None,
#   'Status post femorofemoral bypass surgery': None,
#   'Chronic deep vein thrombosis (DVT) of femoral vein of right lower extremity (CMS-HCC)': None,
#   'Nontraumatic cortical hemorrhage of left cerebral hemisphere (CMS-HCC)': None,
#   'Acute right-sided low back pain with right-sided sciatica': None,
#   'Chronic midline low back pain without sciatica': None,
#   'Squamous cell carcinoma of skin of left upper eyelid including canthus': None,
#   'Female genital prolapse, unspecified type': None,
#   'Arthralgia, unspecified joint': None,
#   'Mediastinal cyst': '748.8',
#   'Brain neoplasm malignant (CMS-HCC)': '191.9',
#   'Malignant neoplasm of kidney (CMS-HCC)': '189.0',
#   'Malignant neoplasm of oropharynx (CMS-HCC)': '146.9',
#   'Scheuermann disease': '732.0',
#   'Pupillary disorder': '379.40',
#   'Cardiac tamponade': '423.3',
#   'Cervical cancer screening': 'V76.2',
#   'Osteoporosis': '733.00',
#   'Hyperplasia of prostate without lower urinary tract symptoms (LUTS)': '600.90',
#   'Exposure to hepatitis C': 'V01.79',
#   'Urethral stricture due to childbirth': '598.1',
#   'Astrocytoma (CMS-HCC)': '191.9',
#   'Left inguinal pain': '789.04',
#   'Anal warts': '078.11',
#   'Bunion, right': '727.1',
#   'Sarcoma of right thigh (CMS-HCC)': None,
#   'Toxic metabolic encephalopathy': None,
#   'Voltage-gated potassium channel antibody syndrome': '349.9',
#   'Hematoma of right thigh, initial encounter': None,
#   'Corneal melt, left': None,
#   'Osteoarthritis of spine with radiculopathy, lumbosacral region': None,
#   'Type III open fracture of right tibia and fibula, initial encounter': None,
#   'Hemodialysis catheter malfunction, initial encounter (CMS-HCC)': None,
#   'Traumatic ecchymosis of left upper arm': None,
#   'Acute hypercapnic respiratory failure (CMS-HCC)': None,
#   'T-cell acute lymphoblastic leukemia (ALL) (CMS-HCC)': None,
#   'Closed fracture of right femur, unspecified fracture morphology, unspecified portion of femur, initial encounter (CMS-HCC)': None,
#   'Arthritis of carpometacarpal (CMC) joint of left thumb': None,
#   'Displaced fracture of distal phalanx of left thumb, initial encounter for closed fracture': None,
#   'Quadriparesis (CMS-HCC)': '344.00',
#   'Sleep disorder': '780.50',
#   'Gunshot injury': 'E922.9',
#   'Diastolic hypertension': '401.9',
#   'Anemia of chronic disease': '285.29',
#   'Chest pressure': '786.59',
#   'Chronic coronary artery disease': '414.00',
#   'Flank pain': '789.00',
#   'Restless legs syndrome': '333.94',
#   'Post-op pain': '338.18',
#   'Melanoma of nasal cavity (CMS-HCC)': '160.0',
#   'Atrial fibrillation and flutter (CMS-HCC)': None,
#   'Closed displaced fracture of condyle of left femur with routine healing': 'V54.15',
#   'Central line clotted (CMS-HCC)': '996.74',
#   'History of amphetamine dependence/abuse (CMS-HCC)': '304.43',
#   'Hx of CABG': 'V45.81',
#   'Abdominal scar neuroma': '215.5',
#   'Thoracic lymphadenopathy': '785.6',
#   'Aspiration into airway': None,
#   'History of melena': None,
#   'History of Clostridium difficile colitis': None,
#   'Diabetic wet gangrene of the foot (CMS-HCC)': '250.70',
#   'Degeneration of intervertebral disc of lumbar region': None,
#   'Closed fracture of right tibial plateau, initial encounter': None,
#   'Blunt trauma to abdomen, initial encounter': None,
#   'Acute on chronic combined systolic (congestive) and diastolic (congestive) heart failure (CMS-HCC)': None,
#   'Infection and inflammatory reaction due to internal right knee prosthesis, initial encounter (CMS-HCC)': None,
#   'Epidermoid cyst of brain': None,
#   'Chronic viral hepatitis B without delta agent and without coma (CMS-HCC)': None,
#   'Atherosclerosis of artery of extremity with rest pain (CMS-HCC)': None,
#   'Minor laceration of liver without open wound into abdominal cavity, initial encounter': None,
#   'Multiple closed fractures of ribs of both sides with routine healing': None,
#   'Compliance with medication regimen': None,
#   'Anaphylactic shock, unspecified, initial encounter': None,
#   'Critical limb ischemia with history of revascularization of same extremity': None,
#   'Nonproliferative diabetic retinopathy of both eyes with macular edema (CMS-HCC)': None,
#   'Postnasal drip': '784.91',
#   'Hepatic encephalopathy (CMS-HCC)': '572.2',
#   'Abdominal aortic aneurysm (CMS-HCC)': '441.4',
#   'Corns and callosities': '700',
#   'Elevated PSA': '790.93',
#   'Pedal edema': '782.3',
#   'Developmental delay': '783.40',
#   'Anxiety and depression': '300.4',
#   'Type 2 diabetes mellitus (CMS-HCC)': '250.00',
#   'Urethral stricture': '598.9',
#   'Retained foreign body': 'V90.9',
#   'Thrombocytosis (CMS-HCC)': '238.71',
#   'Calcaneal fracture': '825.0',
#   'Well woman exam': 'V70.0',
#   'Left leg numbness': '782.0',
#   'History of lumbar discectomy': 'V15.29',
#   'Right pulmonary contusion': '861.21',
#   'Muscle strain of chest wall': '848.8',
#   'Drusen of macula, unspecified laterality': None,
#   'Acute calculous cholecystitis': '574.00',
#   'Plantar fasciitis, bilateral': '728.71',
#   'Supraumbilical hernia': None,
#   'Laceration of left hand involving tendon, initial encounter': None,
#   'Pterygium of eye, right': None,
#   'Vasovagal symptom': None,
#   'Blast injury of hand, left, initial encounter': None,
#   'Malignant neoplasm of cervix, unspecified site (CMS-HCC)': None,
#   'Closed displaced fracture of surgical neck of right humerus, unspecified fracture morphology, initial encounter': None,
#   'Ulcerative pancolitis with other complication (CMS-HCC)': None,
#   'Foot drop, right foot': None,
#   'Amputation of toe of right foot (CMS-HCC)': None,
#   'Diabetic retinopathy of both eyes associated with type 2 diabetes mellitus, macular edema presence unspecified, unspecified retinopathy severity (CMS-HCC)': None,
#   'Perforated diverticulum': None,
#   'Non-seasonal allergic rhinitis due to other allergic trigger': None,
#   'Hair loss': '704.00',
#   'Dyspepsia': '536.8',
#   'Cataract': '366.9',
#   'Status post VNS (vagus nerve stimulator) placement': 'V45.89',
#   'Odynophagia': '787.20',
#   'Facial laceration': '873.40',
#   'Scar of forehead': '709.2',
#   'Separation of cesarean wound with drainage, postpartum': '674.14',
#   'Oscillopsia': '368.15',
#   'Hordeolum externum of left upper eyelid': '373.11',
#   'History of oral cancer': 'V10.02',
#   'Age-related nuclear cataract of both eyes': '366.16',
#   'Elevated intracranial pressure': '781.99',
#   'Hepatic artery embolism (CMS-HCC)': None,
#   'Nasal sinus tumor': '239.1',
#   'Left nephrolithiasis': None,
#   'At risk for sleep apnea': None,
#   'Hemiparesis affecting right side as late effect of cerebrovascular accident (CVA) (CMS-HCC)': None,
#   "Closed Colles' fracture of left radius with routine healing, subsequent encounter": None,
#   'Closed fracture of scaphoid': None,
#   'Stage 3 chronic kidney disease due to diabetes mellitus (CMS-HCC)': None,
#   'Wellness examination': None,
#   'Elevated serum globulin level': None,
#   'AV fistula occlusion, initial encounter (CMS-HCC)': None,
#   'Acute respiratory failure, unsp w hypoxia or hypercapnia (CMS-HCC)': None,
#   'Transient cerebral ischemia, unspecified type': None,
#   'Stricture of anterior urethra in male, unspecified stricture type': None,
#   'Malignant neoplasm of left female breast, unspecified estrogen receptor status, unspecified site of breast (CMS-HCC)': None,
#   'Panic disorder without agoraphobia': '300.01',
#   'Family history of cardiovascular disease': 'V17.49',
#   'Renal artery stenosis (CMS-HCC)': '440.1',
#   'Malignant neoplasm of urethra (CMS-HCC)': '189.3',
#   "Zenker's diverticulum": '530.6',
#   'Neurosyphilis': '094.9',
#   'Elevated blood-pressure reading without diagnosis of hypertension': '796.2',
#   'Emphysema lung (CMS-HCC)': '492.8',
#   'Bilateral hand numbness': '782.0',
#   'CKD (chronic kidney disease) stage 1, GFR 90 ml/min or greater': '585.1',
#   'Malrotation of intestine': '751.4',
#   'History of renal transplant': 'V42.0',
#   'Nonalcoholic fatty liver disease': '571.8',
#   'Rheumatoid nodule (CMS-HCC)': '714.0',
#   'Hepatorenal syndrome (CMS-HCC)': '572.4',
#   'Otosclerosis': '387.9',
#   'Neuromuscular scoliosis of cervicothoracic region': '737.43',
#   'Other dyschromia': '709.09',
#   'History of malignant melanoma': 'V10.82',
#   'Benign positional vertigo': '386.11',
#   'Congenital chordee': '752.63',
#   'Axillary lymphadenopathy': '785.6',
#   'Charcot-Marie-Tooth disease': '356.1',
#   'Soft tissue swelling': '782.2',
#   'S/P colonoscopic polypectomy': 'V45.89',
#   'Gastric ulcer': '531.90',
#   'Cachexia (CMS-HCC)': '799.4',
#   'Radial head fracture': '813.05',
#   'Squamous cell carcinoma of forehead': '173.32',
#   'Chronic midline low back pain with sciatica': None,
#   'Nuclear senile cataract of left eye': None,
#   'Closed fracture of lower extremity': None,
#   'Laceration of leg excluding thigh, right, sequela': None,
#   'Malignant neoplasm of appendix (CMS-HCC)': '153.5',
#   'Diabetic ketoacidosis with coma associated with type 2 diabetes mellitus (CMS-HCC)': None,
#   'Nonsustained paroxysmal ventricular tachycardia (CMS-HCC)': None,
#   'Excessive cerumen in ear canal, bilateral': None,
#   'Pars planitis of left eye': None,
#   'Lid retraction of right eye': None,
#   'Cervical intraepithelial neoplasia (CIN)': '622.10',
#   'Aphakia of eye, right': None,
#   'Hemiplegia affecting non-dominant side, post-stroke': '438.22',
#   'Retinal vasculitis of left eye': '362.18',
#   'Primary open angle glaucoma of both eyes, severe stage': None,
#   'Autism disorder': '299.00',
#   'Ascites': '789.59',
#   "Diarrhea, travelers'": '009.2',
#   "Barrett's esophagus without dysplasia": '530.85',
#   'Closed displaced fracture of greater tuberosity of right humerus': '812.03',
#   'Evisceration of bowel': '553.20',
#   'Achilles tendon contracture, right': '727.81',
#   'Extensor tendon laceration of finger with open wound, initial encounter': None,
#   'Cerebrovascular small vessel disease': '437.9',
#   'History of hyperprolactinemia': 'V12.29',
#   'History of prosthetic heart valve': 'V43.3',
#   'Burn of arm, left, second degree, initial encounter': None,
#   'Advanced care planning/counseling discussion': 'V65.49',
#   'Failure to thrive (0-17)': '783.41',
#   'Secondary malignant neoplasm of bone (CMS-HCC)': '198.5',
#   'Dry eye syndrome, bilateral': None,
#   'Acute loss of vision, left': None,
#   'Free fluid in pelvis': None,
#   'Follicular neoplasm of thyroid': '239.7',
#   'Dislocation of internal right hip prosthesis, subsequent encounter': None,
#   'Neuroendocrine carcinoma metastatic to brain (CMS-HCC)': '209.79',
#   'Abnormal findings on diagnostic imaging of digestive system': '793.4',
#   'Renal pelvis transitional cell malignant neoplasm (CMS-HCC)': '189.1',
#   'Primary osteoarthritis involving multiple joints': None,
#   'Presence of artificial knee joint, bilateral': None,
#   'Breast wound, left, subsequent encounter': None,
#   'ST elevation myocardial infarction involving left anterior descending (LAD) coronary artery (CMS-HCC)': None,
#   'Severe peripheral arterial disease (CMS-HCC)': None,
#   'Recurrent deep vein thrombosis (DVT) (CMS-HCC)': None,
#   'Closed displaced oblique fracture of shaft of left humerus, initial encounter': None,
#   'Granulosa cell tumor of ovary, right': None,
#   'Biliary sludge determined by ultrasound': None,
#   'Vaginal bleeding during pregnancy, antepartum': None,
#   'Acute renal failure superimposed on chronic kidney disease (CMS-HCC)': None,
#   'Fracture of seventh thoracic vertebra (CMS-HCC)': None,
#   'History of anticoagulant therapy': None,
#   'Ankylosing spondylitis, unspecified site of spine (CMS-HCC)': None,
#   'Other urethral stricture (CODE)': None,
#   'Acquired trigger finger of right middle finger': None,
#   'Cervical Papanicolaou smear negative within last 12 months': None,
#   'Encounter for preoperative evaluation of living donor of kidney': None,
#   'Mixed type age-related cataract, both eyes': None,
#   'Acquired blepharoptosis of right eyelid': None,
#   'Closed displaced fracture of medial malleolus of right tibia, initial encounter': None,
#   'Vitreous degeneration, left': None,
#   "Crohn's colitis, unspecified complication (CMS-HCC)": None,
#   'Glasgow coma scale total score 3-8, 24 hours or more after hospital admission (CMS-HCC)': None,
#   'Recent change in frequency of bowel movements': None,
#   'Borderline hyperglycemia': None,
#   'Cellulitis of left elbow': None,
#   'Canalicular eyelid laceration, left, initial encounter': None,
#   'Sepsis due to gram-negative urinary tract infection (CMS-HCC)': None,
#   'Other persistent atrial fibrillation': None,
#   'Sixth nerve palsy': '378.54',
#   'DKA (diabetic ketoacidosis) (CMS-HCC)': '250.10',
#   'Sicca syndrome (CMS-HCC)': '710.2',
#   'Posttraumatic stress disorder': '309.81',
#   'Dysfunction of eustachian tube': '381.81',
#   'Malignant neoplasm of central portion of female breast (CMS-HCC)': '174.1',
#   'Abdominal pain, generalized': '789.07',
#   'Chronic fatigue syndrome': '780.71',
#   'Subserous leiomyoma of uterus': '218.2',
#   'Patent foramen ovale': '745.5',
#   'Old myocardial infarction': '412',
#   'Conjunctival concretions': '372.54',
#   'Headache around the eyes': '784.0',
#   'Epilepsy symptomatic, generalized (CMS-HCC)': '345.90',
#   'Malignant neoplasm of lung (CMS-HCC)': '162.9',
#   'Neck pain on right side': '723.1',
#   'Anticoagulated on warfarin': 'V58.61',
#   'HLA B27 (HLA B27 positive)': 'V84.89',
#   'Thoracic cysts': '748.8',
#   'Advance care planning': 'V65.49',
#   'Epididymitis': '604.90',
#   'Fractures': '829.0',
#   'Combined form of senile cataract': '366.19',
#   'Sickle-cell anemia (CMS-HCC)': '282.60',
#   'Burn of knee, left, second degree, initial encounter': None,
#   'LVAD (left ventricular assist device) present (CMS-HCC)': 'V45.09',
#   'Food impaction of esophagus, initial encounter': None,
#   'Closed fracture of manubrium with routine healing': None,
#   'Adhesive middle ear disease of right side': '385.10',
#   'AMA (advanced maternal age) multigravida 35+, third trimester': None,
#   'Aortic regurgitation due to bicuspid aortic valve': None,
#   'Arthralgia of right lower leg': '719.46',
#   'Small B-cell lymphoma of lymph nodes of multiple regions (CMS-HCC)': None,
#   'Afib (CMS-HCC)': '427.31',
#   'Abnormal ultrasound of liver': '793.3',
#   'VBI (vertebrobasilar insufficiency)': '435.3',
#   'Hx of syncope': 'V13.89',
#   'Acquired leg length discrepancy': '736.81',
#   'Herniated lumbar intervertebral disc': '722.10',
#   'Acquired dysmorphic toenail': '703.8',
#   'Asthma with COPD (chronic obstructive pulmonary disease) (CMS-HCC)': '493.20',
#   'Sinus infection': '473.9',
#   'Solitary kidney, acquired': 'V45.73',
#   'Primary open-angle glaucoma': None,
#   'Varicose veins of right lower extremity': None,
#   'Alpha thalassemia (CMS-HCC)': '282.43',
#   'History of revision of total replacement of right hip joint': None,
#   'Coagulation defect, unspecified (CMS-HCC)': None,
#   'Anterior basement membrane dystrophy (ABMD) of both eyes': None,
#   'Restenosis of arterial stent (CMS-HCC)': None,
#   'Facial droop': '781.94',
#   'Lumbar spinal stenosis': '724.02',
#   'Surgical abdomen': '789.00',
#   'BI-RADS category 3 mammogram result': None,
#   'Cicatrizing conjunctivitis': None,
#   'Vitreous prolapse of left eye': '379.26',
#   'Acute cystitis with hematuria': '595.0',
#   'Musculoskeletal neck pain': '723.1',
#   'Pneumonitis': '486',
#   'Hormone disturbance': '259.9',
#   'Chronic cystitis with hematuria': None,
#   'Vitreomacular adhesion, unspecified laterality': None,
#   'Presence of Watchman left atrial appendage closure device': None,
#   'Primary open angle glaucoma of left eye, mild stage': None,
#   'Decreased GFR': '794.4',
#   'Type III open displaced oblique fracture of shaft of right femur, initial encounter (CMS-HCC)': None,
#   'Abnormal computed tomography of cecum and terminal ileum': '793.4',
#   'Acute rejection of kidney transplant': '996.81',
#   'Low grade mucinous neoplasm of appendix': '239.0',
#   'Major depression, recurrent (CMS-HCC)': '296.30',
#   'HLA-B27 spondyloarthropathy': '721.90',
#   'Routine physical examination': 'V70.0',
#   'Numbness of lower limb': '782.0',
#   'Bicuspid aortic valve determined by imaging': None,
#   'Burn, hands, second degree, right, initial encounter': None,
#   'Insulinoma': '211.7',
#   'Tumor lysis syndrome': '277.88',
#   'Bicycle accident': 'E826.9',
#   'Spastic hemiparesis of right dominant side (CMS-HCC)': None,
#   'Complication of implanted vaginal mesh, initial encounter': None,
#   'Hemorrhagic ovarian cyst': '620.2',
#   'Steroid responder, right eye': None,
#   'Chronic left hip pain': '719.45',
#   'Closed displaced fracture of posterior wall of left acetabulum with routine healing': None,
#   'Infection of nose': None,
#   'Quadriplegia, C5-C7 complete (CMS-HCC)': '344.03',
#   'Hx of hysterectomy for benign disease': 'V88.01',
#   'S/P aortic valve replacement with bioprosthetic valve': 'V43.3',
#   'Decubitus ulcer, stage 1': '707.00',
#   'Cancer, true vocal cords (CMS-HCC)': '161.0',
#   'Lumbar adjacent segment disease with spondylolisthesis': None,
#   'Closed fracture of proximal lateral malleolus of right fibula': None,
#   'Supervision of elderly multigravida, unspecified trimester': None,
#   'Benign prostatic hyperplasia with urinary frequency': None,
#   'Bilateral non-suppurative otitis media': '381.4',
#   'Benign meningioma of brain (CMS-HCC)': None,
#   'Colonic mass': '569.89',
#   'Painful orthopaedic hardware (CMS-HCC)': None,
#   'History of parathyroidectomy (CMS-HCC)': 'V15.29',
#   'Tongue wound': '873.64',
#   'Symptoms of upper respiratory infection (URI)': None,
#   'Encounter for counseling for travel': None,
#   'Optic atrophy of right eye': '377.10',
#   'Renal cell carcinoma of right kidney (CMS-HCC)': None,
#   'Pain, foot, left, chronic': '729.5',
#   'Contracture of left elbow': '718.42',
#   'Previous back surgery': 'V45.89',
#   'Clotted dialysis access, initial encounter (CMS-HCC)': None,
#   'Closed displaced comminuted fracture of shaft of left tibia with nonunion': '733.82',
#   'CAD, multiple vessel': '414.00',
#   'Encounter for current long-term use of anticoagulants': None,
#   "Raynaud's syndrome without gangrene": '443.0',
#   'Subacromial impingement of left shoulder': None,
#   'Fibroadenoma of left breast': None,
#   'Abnormal skin growth': None,
#   'Uses hearing aid': None,
#   'Diuretic-induced hypokalemia': '276.8',
#   'E. coli UTI (urinary tract infection)': '599.0',
#   'COPD, very severe (CMS-HCC)': '496',
#   'History of vitamin D deficiency': 'V12.1',
#   'Elbow wound, left, initial encounter': None,
#   'Bile duct abnormality': '576.9',
#   'Long term current use of immunosuppressive drug': None,
#   'Right trigeminal neuralgia': None,
#   'Bilateral breast cysts': None,
#   'Dichorionic diamniotic twin gestation': 'V91.03',
#   'Ruptured globe of left eye, subsequent encounter': None,
#   'Mastoiditis of both sides': '383.9',
#   'Screening and evaluation for female sterilization': 'V25.09',
#   'Diabetic nephropathy associated with type 1 diabetes mellitus (CMS-HCC)': None,
#   'Bacteremia due to Streptococcus': '790.7',
#   'Malignant neoplasm metastatic to cortex of left adrenal gland with unknown primary site (CMS-HCC)': None,
#   'Closed left subtrochanteric femur fracture, with routine healing, subsequent encounter': None,
#   'Urethral stricture in male': None,
#   'Localized primary osteoarthritis of carpometacarpal (CMC) joint of right wrist': None,
#   'Closed displaced fracture of first cervical vertebra, unspecified fracture morphology, initial encounter (CMS-HCC)': None,
#   'Burn of foot, deep third degree, right, initial encounter': None,
#   'Laceration of right thigh, initial encounter': None,
#   'Benign paroxysmal positional vertigo due to bilateral vestibular disorder': None,
#   'Age-related vocal fold atrophy': None,
#   'Arthritis of left wrist': None,
#   'Congenital adrenal hyperplasia due to 21-hydroxylase deficiency (21-OH CAH), simple virilizing (CMS-HCC)': '255.2',
#   'Ulnar neuropathy at elbow, right': None,
#   'COVID-19 virus detected': None,
#   'Drusen (degenerative) of retina, bilateral': None,
#   'E coli bacteremia': '790.7',
#   'Stage 3 chronic kidney disease, unspecified whether stage 3a or 3b CKD (CMS-HCC)': None,
#   'Type 2 diabetes mellitus with stage 3 chronic kidney disease, with long-term current use of insulin, unspecified whether stage 3a or 3b CKD (CMS-HCC)': None,
#   'Acquired absence of breast and absent nipple, bilateral': None,
#   'Ion (ischemic optic neuropathy), left': None,
#   'Atherosclerosis of native arteries of extremities with intermittent claudication, bilateral legs (CMS-HCC)': None,
#   'Malignant melanoma of left lower extremity (CMS-HCC)': None,
#   'Open fracture distal humerus, bicondylar (T-Y fracture), left, initial encounter': None,
#   'Decreased hearing of both ears': None,
#   'Closed fracture of facial bone, unspecified facial bone, initial encounter (CMS-HCC)': None,
#   'Full thickness burn of left hand, sequela': None,
#   'Malignant neoplasm of breast in female, estrogen receptor negative (CMS-HCC)': None,
#   'Hemiplegia and hemiparesis following cerebral infarction affecting right dominant side (CMS-HCC)': None,
#   'Acquired absence of breast, bilateral': None,
#   'Peripheral polyneuropathy': '356.9',
#   'Posterior subcapsular age-related cataract of right eye': None,
#   'Body mass index (BMI) of less than 5th percentile for age in patient 18 years to less than 21 years of age': None,
#   "Keratoconjunctivitis sicca of both eyes not due to Sjogren's syndrome": None,
#   'Ectopic pregnancy without intrauterine pregnancy, unspecified location': None,
#   'Mild nonproliferative diabetic retinopathy of right eye without macular edema associated with type 2 diabetes mellitus (CMS-HCC)': None,
#   'Sacral insufficiency fracture with malunion': None,
#   'Type 2 diabetes mellitus with foot ulcer, without long-term current use of insulin (CMS-HCC)': None,
#   'Class 1 obesity without serious comorbidity with body mass index (BMI) of 33.0 to 33.9 in adult, unspecified obesity type': None,
#   'Bedbound': None,
#   'Hemiparesis of left nondominant side as late effect of nontraumatic intracerebral hemorrhage (CMS-HCC)': None,
#   "Perianal fistula due to Crohn's disease (CMS-HCC)": None,
#   'Calculus of gallbladder': '574.20',
#   'Retrosternal chest pain': '786.51',
#   'Raynaud phenomenon': '443.0',
#   'Enterocele': '553.9',
#   'Cancer with metastasis to bladder (CMS-HCC)': '198.1',
#   'Toe fracture, left': '826.0',
#   'Hypermetropia of both eyes': '367.0',
#   'Antineoplastic chemotherapy induced pancytopenia (CMS-HCC)': None,
#   'Primary malignant neoplasm of pelvis (CMS-HCC)': '195.3',
#   'S/P revision of total knee, right': None,
#   'AVM (arteriovenous malformation) of stomach, acquired': None,
#   'Third degree burn of multiple sites of right wrist, sequela': None,
#   'Necrosis of surgical wound, initial encounter': None,
#   'Neuropathy of right foot': None,
#   'Neoplasm of right breast, primary tumor staging category Tis: ductal carcinoma in situ (DCIS)': None,
#   'Multiple fractures due to automobile collision': None,
#   'History of low transverse cesarean section': None,
#   'Acute ST elevation myocardial infarction (STEMI) involving other coronary artery of anterior wall (CMS-HCC)': None,
#   'Astigmatism of both eyes, unspecified type': None,
#   'Infection of superficial incisional surgical site after procedure': None,
#   'Chronic interstitial cystitis': '595.1',
#   'Complications due to cardiac device, implant, and graft': '996.72',
#   'Retinal disorder': '362.9',
#   'Balance problems': '781.99',
#   'Caustic esophageal injury': '947.2',
#   'Chest wall contusion': '922.1',
#   'Debilitated patient': '799.3',
#   'Peripheral polyneuropathy (CMS-HCC)': '356.9',
#   'Closed fracture of shaft of right femur with routine healing': 'V54.15',
#   'Condyloma acuminatum of penis': '078.11',
#   'Tinnitus, unspecified laterality': None,
#   'Drug-induced hepatotoxicity': '573.3',
#   'Type I or II open fracture of proximal end of tibia, unspecified fracture morphology, unspecified laterality, initial encounter': None,
#   'Hypotension of hemodialysis': '458.21',
#   'Retinitis': '363.20',
#   'Sacral spinal cord injury (CMS-HCC)': '952.3',
#   'Supervision of normal pregnancy': 'V22.1',
#   'Abdominal hernia': '553.9',
#   'Pre-syncope': '780.2',
#   'Acquired scoliosis': '737.30',
#   'Blepharoconjunctivitis due to herpes simplex virus': '054.41',
#   'Spontaneous ecchymosis': '782.7',
#   'Soft tissue infection of foot': '686.9',
#   'Right inguinal pain': '789.03',
#   'Chronic wound infection of abdomen': '958.3',
#   'Open wound of left foot, initial encounter': None,
#   'Thrombosis of vascular graft, initial encounter (CMS-HCC)': None,
#   'Chronic kidney disease (CKD), active medical management without dialysis, stage 3 (moderate)': None,
#   'AV fistula stenosis, subsequent encounter': None,
#   'Dislocation of right talus, initial encounter': None,
#   'Diabetes mellitus, antepartum': None,
#   'Chronic left lumbar radiculopathy': None,
#   'Hypodense mass of liver': None,
#   'Adenomatous polyp of transverse colon': None,
#   'Traumatic brain injury, with loss of consciousness greater than 24 hours without return to pre-existing conscious level with patient surviving, initial encounter (CMS-HCC)': None,
#   'Diabetes mellitus due to underlying condition with hyperosmolarity without coma, unspecified whether long term insulin use (CMS-HCC)': None,
#   'Blepharitis of upper and lower eyelids of both eyes, unspecified type': None,
#   'Chronic rupture of MCL of right knee': None,
#   'Closed displaced bimalleolar fracture of left ankle with routine healing, subsequent encounter': None,
#   'Major depressive disorder, single episode, mild (CMS-HCC)': '296.21',
#   'Papanicolaou smear of cervix with atypical squamous cells cannot exclude high grade squamous intraepithelial lesion (ASC-H)': '795.02',
#   'PAC (premature atrial contraction)': '427.61',
#   'Uterine cancer (CMS-HCC)': '179',
#   'Hepatic metastases (CMS-HCC)': '197.7',
#   'Other facial nerve disorders': '351.8',
#   'Enthesopathy': '726.90',
#   'Hyperkalemia, diminished renal excretion': '276.7',
#   'VIN III (vulvar intraepithelial neoplasia III)': '233.32',
#   'Otogenic otalgia': '388.71',
#   'Ruptured globe': '871.0',
#   'Pleural effusion, left': '511.9',
#   'Combined forms of age-related cataract of right eye': '366.19',
#   'History of cardiac arrhythmia': 'V12.59',
#   'C7 cervical fracture (CMS-HCC)': '805.07',
#   'Closed displaced transverse fracture of right patella, initial encounter': None,
#   'Alcohol withdrawal syndrome without complication (CMS-HCC)': None,
#   'MVC (motor vehicle collision), sequela': None,
#   'Primary open angle glaucoma of right eye, mild stage': None,
#   'Perforated sigmoid colon (CMS-HCC)': None,
#   'History of bilateral tubal ligation': None,
#   'Alcoholic intoxication without complication (CMS-HCC)': None,
#   'Floaters with photopsia': None,
#   'Pulmonary hypertension, unspecified (CMS-HCC)': None,
#   'Diabetes insipidus (CMS-HCC)': '253.5',
#   'Neurodermatitis': '698.3',
#   'Disorder of bone and cartilage': '733.90',
#   'Engorgement of breast': '611.79',
#   'Cervical postlaminectomy syndrome': '722.81',
#   'Optic neuropathy, left': '377.39',
#   'Impingement syndrome of right shoulder': '726.2',
#   'Presence of artificial eye': 'V43.0',
#   'Squamous cell carcinoma of neck': '173.42',
#   'Burn of buttock, second degree, sequela': None,
#   'Chronic osteomyelitis of left tibia (CMS-HCC)': None,
#   'Hematoma of right thigh': None,
#   'IUD contraception': 'V45.51',
#   'History of reflex sympathetic dystrophy': 'V12.49',
#   'Squamous cell carcinoma of skin of orbit': '173.12',
#   'Other acute recurrent sinusitis': None,
#   'Chronic, continuous use of opioids': '304.01',
#   'Superficial venous thrombosis of right upper extremity': None,
#   'Other acute osteomyelitis of left foot (CMS-HCC)': None,
#   'Open fracture of right orbital floor, initial encounter (CMS-HCC)': None,
#   'Type 2 diabetes mellitus with obesity (CMS-HCC)': None,
#   'Hiccups': '786.8',
#   'Complicated urinary tract infection': '599.0',
#   'Chronic type B viral hepatitis (CMS-HCC)': '070.32',
#   'Visual field defects': '368.40',
#   'Preprocedural cardiovascular examination': 'V72.81',
#   'Vulvar abscess': '616.4',
#   'Mantle cell lymphoma (CMS-HCC)': '200.40',
#   'Cystoid macular edema of left eye': '362.53',
#   'Acquired clawhand': '736.06',
#   'Post-operative complication': '998.9',
#   'Chest trauma, penetrating': '862.9',
#   'Rectal abnormality': '569.49',
#   'Carcinoma in situ of exocervix': '233.1',
#   'Secondary glaucoma due to combination mechanisms, left, severe stage': None,
#   'Infection of prosthetic total hip joint, subsequent encounter': None,
#   'Decubitus ulcer of both feet, stage 2 (CMS-HCC)': None,
#   'Myopia, right eye': None,
#   'Malignant neoplasm of nipple of right breast in female, unspecified estrogen receptor status (CMS-HCC)': None,
#   'Urethral hypermobility': '599.81',
#   'HAV (hallux abducto valgus)': '735.0',
#   'Severe headache': '784.0',
#   'Enlarged LA (left atrium)': '429.3',
#   'Primary squamous cell carcinoma of head and neck (CMS-HCC)': '195.0',
#   'Complete lesion of thoracic spinal cord (CMS-HCC)': '952.9',
#   'Thoracic vertebral fracture (CMS-HCC)': '805.2',
#   'Perforated appendicitis': '540.0',
#   'Memory difficulty': '780.93',
#   'Left buttock pain': '729.1',
#   'Vitreous hemorrhage, unspecified laterality (CMS-HCC)': None,
#   'Difficult airway for intubation, subsequent encounter': None,
#   'Caregiver role strain': 'IMO0001',
#   'History of robot-assisted laparoscopic hysterectomy': None,
#   'S/P AKA (above knee amputation) unilateral, left (CMS-HCC)': None,
#   'Adverse effect of paclitaxel, sequela': None,
#   'Type III open fracture dislocation of right ankle joint, with routine healing, subsequent encounter': None,
#   'Other atopic dermatitis': None,
#   'Acute angle-closure glaucoma, right eye': None,
#   'Unilateral primary osteoarthritis, left knee': None,
#   'Enlarged lymph node in neck': None,
#   'Status post coronary artery stent placement': 'V45.82',
#   'Hypertrophy of prostate with urinary obstruction': '600.01',
#   'History of gestational diabetes in prior pregnancy, currently pregnant': 'V23.49',
#   'Encounter for fertility preservation counseling': 'V26.42',
#   'Malignant neoplasm of left female breast (CMS-HCC)': '174.9',
#   'Glaucoma associated with ocular trauma, indeterminate stage': '365.65',
#   'SLE exacerbation (CMS-HCC)': '710.0',
#   'Single acquired cyst of kidney': '593.2',
#   'Heterozygous MTHFR mutation C677T (CMS-HCC)': '270.4',
#   'Encounter for counseling regarding contraception': None,
#   'Malfunction of arteriovenous graft (CMS-HCC)': None,
#   'Blepharitis of upper and lower eyelids of both eyes': None,
#   'H/O total ankle replacement, right': None,
#   'Conductive hearing loss, unilateral, right ear, with unrestricted hearing on the contralateral side': None,
#   'External otitis of left ear due to fungus': None,
#   'Chronic recurrent multifocal osteomyelitis (CMS-HCC)': None,
#   'Other systemic lupus erythematosus with tubulo-interstitial nephropathy (CMS-HCC)': None,
#   'Class 3 severe obesity with body mass index (BMI) of 40.0 to 44.9 in adult, unspecified obesity type, unspecified whether serious comorbidity present (CMS-HCC)': None,
#   'Persistent hyperplasia of thymus (CMS-HCC)': '254.0',
#   'Bursitis': '727.3',
#   'Cleft lip, unilateral': '749.12',
#   'Infectious diarrhea': None,
#   'Knee effusion, right': '719.06',
#   'S/P arthroscopy of left knee': 'V45.89',
#   'Grand mal status (CMS-HCC)': '345.3',
#   'Contracture of right elbow': '718.42',
#   'Burn of face and head': '941.00',
#   'Decubital ulcer': '707.00',
#   'Blood clotting disorder (CMS-HCC)': '286.9',
#   'Fracture, ribs': '807.00',
#   'Vocal cord dysfunction': '478.5',
#   'Corneal scar': '371.00',
#   'History of surgical procedure': 'V45.89',
#   'Controlled type 1 diabetes mellitus (CMS-HCC)': None,
#   'Numbness of left lower extremity': None,
#   'Leukocytopenia': '288.50',
#   'SVD (spontaneous vaginal delivery)': '650',
#   'Vaccine refused by patient': 'V64.09',
#   'Closed displaced fracture of middle phalanx of right middle finger': '816.01',
#   'Fracture of orbital roof': '801.00',
#   'History of enucleation of right eyeball': 'V15.29',
#   'Status post skin graft': 'V42.3',
#   'Hand crush injury, right, initial encounter': None,
#   'Bilateral breast cancer (CMS-HCC)': None,
#   'Ureter injury, initial encounter': None,
#   'History of end stage renal disease': None,
#   'Fracture of ribs, two, right, closed, initial encounter': None,
#   'Lip edema': '528.5',
#   'Malfunction of arteriovenous dialysis fistula, sequela': None,
#   'Recurrent obstructive pyelonephritis': '590.80',
#   'History of cardiac pacemaker in situ': None,
#   'Transient speech disturbance': None,
#   'Family history of systemic lupus erythematosus (SLE) in mother': None,
#   'Cancer of head, face, or neck lymph nodes, secondary (CMS-HCC)': '196.0',
#   'Knee arthropathy': '716.96',
#   'Burn of leg, second degree, left, initial encounter': None,
#   'Physiologic cupping of optic disc of both eyes': None,
#   'Isoimmunization from blood group incompatibility during pregnancy in second trimester': None,
#   'Basal cell carcinoma of skin of right wrist': None,
#   'History of drug abuse in remission (CMS-HCC)': '305.93',
#   'Posterior glottic stenosis': '478.74',
#   'Diverticulitis of large intestine with perforation without abscess, unspecified bleeding status': None,
#   'Acquired phimosis of penis': None,
#   'Thrombosis of ovarian vein': None,
#   'History of precipitous labor and deliveries in third trimester, antepartum': None,
#   'Anatomical narrow angle glaucoma of left eye': None,
#   'Ovarian tumor of borderline malignancy, left': None,
#   'Deformity of right ankle joint': None,
#   'Traumatic amputation of left arm above elbow, initial encounter (CMS-HCC)': None,
#   'S/P peripheral artery angioplasty with stent placement': None,
#   'Medium size artery vasculitis (CMS-HCC)': None,
#   'Acne rosacea': '695.3',
#   'Iatrogenic cerebrovascular infarction or hemorrhage': '997.02',
#   'Motor vehicle collision with pedestrian, injuring unspecified person': 'E814.9',
#   'Cellulitis of abdominal wall': '682.2',
#   'Epididymal cyst': '608.89',
#   'Generalized hyperhidrosis': '780.8',
#   'Paroxysmal ventricular tachycardia': '427.1',
#   'Impetigo': '684',
#   'Disease of lung': '518.89',
#   'Macromastia': '611.1',
#   'Need for prophylactic vaccination and inoculation against influenza': 'V04.81',
#   'Multiple bruises': '924.8',
#   'Nonfunctioning kidney': '593.9',
#   'Right hemiplegia (CMS-HCC)': '342.90',
#   'TMJ disorder involving articular disc abnormality': '524.63',
#   'Acute on chronic diastolic congestive heart failure (CMS-HCC)': '428.33',
#   'Gastrojejunostomy tube dislodgement': '569.62',
#   'Brain bleed (CMS-HCC)': '431',
#   'Preoperative examination, unspecified': 'V72.84',
#   'Acute appendicitis with generalized peritonitis': '540.0',
#   'Breast pain, right': '611.71',
#   'Stab wound of abdominal wall with complication, initial encounter': None,
#   'Perforated corneal ulcer of left eye': '370.06',
#   'Lesion of lip': '528.5',
#   'Hepatitis C virus infection without hepatic coma': None,
#   'Lens dislocation and subluxation, left': None,
#   'Libido, decreased': '799.81',
#   'Ependymoma (CMS-HCC)': '191.9',
#   'Sarcoma, endometrial stromal (CMS-HCC)': '182.0',
#   'Fibromyositis': '729.1',
#   'Atrial septal defect': '745.5',
#   'PD catheter dysfunction, initial encounter (CMS-HCC)': None,
#   'Shoulder dislocation, left, subsequent encounter': None,
#   'Contusion of right lung': '861.21',
#   'Mixed conductive and sensorineural hearing loss of left ear with restricted hearing of right ear': None,
#   'Skin ulcer, unspecified ulcer stage (CMS-HCC)': None,
#   'Contact dermatitis, unspecified contact dermatitis type, unspecified trigger': None,
#   'Primary adenocarcinoma of upper lobe of right lung (CMS-HCC)': None,
#   'Paronychia of finger of left hand': None,
#   'Traumatic closed displaced fracture of shaft of left humerus with nonunion': None,
#   'Pneumonia of both lungs due to infectious organism, unspecified part of lung': None,
#   'Acquired absence of uterus with remaining cervical stump': 'V88.02',
#   'Lumbar scoliosis': '737.30',
#   'Family history of peptic ulcer': 'V18.59',
#   'Abdominal aneurysm': '441.4',
#   'Hand lesion': '709.9',
#   'Pain in left tibia': None,
#   'Open wound of abdomen, subsequent encounter': None,
#   'Encounter for supervision of primigravida of advanced maternal age in first trimester': None,
#   'Aftercare for healing traumatic closed fracture of left tibia': None,
#   'Dry skin dermatitis': '692.89',
#   'Carcinoma of ovary, unspecified laterality (CMS-HCC)': None,
#   'Injury of head': '959.01',
#   'Diabetes mellitus type 2, controlled (CMS-HCC)': '250.00',
#   'Acute cerebellar hemorrhage (CMS-HCC)': '431',
#   'Stenosis of celiac artery (CMS-HCC)': '447.4',
#   'Pain of left breast': '611.71',
#   'Hyponatremia syndrome': '276.1',
#   'At risk for retention of urine': None,
#   'Decubitus ulcer of trochanter, stage 3, right (CMS-HCC)': None,
#   'Closed displaced fracture of base of fifth metacarpal bone of left hand with routine healing': None,
#   'Lower extremity cellulitis': '682.6',
#   'Open displaced transverse fracture of shaft of left tibia': None,
#   'Lesion of liver': '573.8',
#   'Mixed aphasia': '784.3',
#   'H/O hiatal hernia': 'V12.79',
#   'Migraine aura without headache': '346.00',
#   'Cervical spine pain': '723.1',
#   'Osteoarthritis of AC (acromioclavicular) joint': None,
#   'Joint stiffness of both knees': None,
#   'Moderate vulvar dysplasia': '624.02',
#   'Muscle spasm of both lower legs': '728.85',
#   'Left lower lobe pneumonia': '486',
#   'Renal lesion': '593.9',
#   'Thoracic degenerative disc disease': '722.51',
#   'Hernia': '553.9',
#   'Vitreomacular adhesion of right eye': '379.27',
#   'Rupture of anterior cruciate ligament of right knee, subsequent encounter': None,
#   'Encounter for screening involving social determinants of health (SDoH)': None,
#   'Chills (without fever)': '780.64',
#   'Intradural mass (CMS-HCC)': None,
#   'Trigger finger, left': '727.03',
#   'Screening for diabetic retinopathy': 'V80.2',
#   'Varicose veins of both lower extremities with pain': '454.8',
#   'Pneumothorax with hemothorax, traumatic, initial encounter': None,
#   'Aphasia following cerebrovascular accident (CVA)': None,
#   'BPPV (benign paroxysmal positional vertigo), left': None,
#   'Chronic deep vein thrombosis (DVT) of both upper extremities, unspecified vein (CMS-HCC)': None,
#   'Developmental abnormality of central nervous system (CMS-HCC)': '742.9',
#   'Traumatic degenerative joint disease of foot, left': None,
#   'Dislocation of internal right hip prosthesis, initial encounter (CMS-HCC)': None,
#   'H/O mastectomy, right': None,
#   'Intermittent right upper quadrant abdominal pain': None,
#   'Bilateral hand swelling': None,
#   'Aneurysmal bone cyst of left tibia': None,
#   'Renal cancer, right (CMS-HCC)': None,
#   'Left groin mass': None,
#   'Interstitial myositis of multiple sites': '728.81',
#   'Pain and swelling of lower leg, right': None,
#   'Abdominal wall hernia': '553.20',
#   'Breakdown (mechanical) of vascular dialysis catheter, initial encounter (CMS-HCC)': None,
#   'History of pituitary adenoma': None,
#   'Other mechanical complication of internal fixation device of other bone, sequela': None,
#   'Primary cholangiocarcinoma of intrahepatic bile duct (CMS-HCC)': None,
#   'Mult fx of pelvis w unstable disrupt of pelvic ring, init (CMS-HCC)': None,
#   'High frequency hearing loss of both ears': None,
#   'Atypical squamous cell changes of undetermined significance (ASCUS) on cervical cytology with negative high risk human papilloma virus (HPV) test result': None,
#   'Traction retinal detachment sparing macula, right': None,
#   'Airway compromise': '519.8',
#   'Rh negative state in antepartum period, third trimester': None,
#   'Unspecified fracture of left acetabulum, initial encounter for closed fracture (CMS-HCC)': None,
#   'Acute stroke due to ischemia (CMS-HCC)': None,
#   'Other generalized epilepsy, intractable, with status epilepticus (CMS-HCC)': None,
#   'Migraine without status migrainosus': None,
#   'Breast cancer associated with mutation in ATM gene (CMS-HCC)': None,
#   'Dependence on respirator (ventilator) status (CMS-HCC)': None,
#   'Burn of left leg, second degree, initial encounter': None,
#   'Mild intermittent reactive airway disease without complication': None,
#   'Pulmonary fibrosis, unspecified (CMS-HCC)': None,
#   'Lymphedema of both arms': None,
#   'Intra-abdominal adhesions': None,
#   'Closed fracture of transverse process of thoracic vertebra, initial encounter (CMS-HCC)': None,
#   'Abdominal bloating with cramps': None,
#   'Deep vein thrombosis (DVT) of femoral vein of right lower extremity (CMS-HCC)': None,
#   'Thrombotic microangiopathy (CMS-HCC)': '446.6',
# ...
#   'Open thigh wound, left, initial encounter': 684,
#   'Skin sensitivity': 685,
#   'Gait disorder': 686,
#   'Sepsis due to Streptococcus species without acute organ dysfunction (CMS-HCC)': 687,
#   'Intractable headache': 688,
#   'Premature cervical dilation in third trimester': 689,
#   'Type 1 diabetes mellitus with obesity (CMS-HCC)': 690,
#   'Ankle joint deformity, right': 691,
#   'Thrombus of pulmonary vein (CMS-HCC)': 692,
#   'Papillary serous adenocarcinoma of ovary, unspecified laterality (CMS-HCC)': 693,
#   'Burn of thigh, second degree, right, initial encounter': 694,
#   'Encephalomalacia': 695,
#   'PIN III (prostatic intraepithelial neoplasia III)': 696,
#   'Deep vein thrombosis (DVT) of both upper extremities (CMS-HCC)': 697,
#   'Neoplasm of cecum': 698,
#   'Cataract extraction status of right eye': 699,
#   'Age-related nuclear cataract, right': 700,
#   'Intractable post-traumatic headache, unspecified chronicity pattern': 701,
#   'Mass of hand, bilateral': 702,
#   'Heterozygous thalassemia': 703,
#   'Ex-cigarette smoker': 704,
#   'Acute renal failure with other specified pathological lesion in kidney (CMS-HCC)': 705,
#   'Bite wound of right thumb': 706,
#   'Paralytic lagophthalmos left lower eyelid': 707,
#   'Left ventricular hypertrophy due to hypertensive disease': 708,
#   'Ulnar abutment syndrome of right wrist': 709,
#   'Failed total right knee replacement, subsequent encounter': 710,
#   'Encounter for screening for COVID-19': 711,
#   'Closed displaced segmental fracture of shaft of left tibia with nonunion, subsequent encounter': 712,
#   'Paronychia of great toe, left': 713,
#   'Hepatic vein occlusion (CMS-HCC)': 714,
#   'Trigger finger, right middle finger': 715,
#   'Status post radiation therapy': 716,
#   'Glossodynia': 717,
#   'EBT (electron beam tomography) abnormal': 718,
#   'Gram-negative pneumonia (CMS-HCC)': 719,
#   'Chest trauma, penetrating': 720,
#   'S/P hernia surgery': 721,
#   'Encounter for insertion of copper IUD': 722,
#   'Schizoaffective disorder, bipolar type with good prognostic features (CMS-HCC)': 723,
#   'Varicose veins of lower extremity with ulcer of calf of other severity, unspecified laterality (CMS-HCC)': 724,
#   'Enlarged and hypertrophic nails': 725,
#   'Chronic intracerebral hemorrhage (CMS-HCC)': 726,
#   'Insomnia due to mental disorder': 727,
#   'Hyperactivity disorder': 728,
#   'Osteoporosis with current pathological fracture': 729,
#   'Closed fracture of orbit with delayed healing, subsequent encounter': 730,
#   'Ductal carcinoma of breast, left (CMS-HCC)': 731,
#   'Senile cataract': 732,
#   'Heart failure with preserved left ventricular function (HFpEF) (CMS-HCC)': 733,
#   'Paresthesia of skin': 734,
#   'Cellulitis of right lower limb': 735,
#   'Closed fracture of distal radius and ulna, initial encounter': 736,
#   'Angular cheilitis with candidiasis': 737,
#   'Encounter for surgical aftercare following surgery of sense organs': 738,
#   'Right leg claudication (CMS-HCC)': 739,
#   'Closed fracture of medial condyle of distal humerus, left, initial encounter': 740,
#   'Mechanical complication of bypass graft, initial encounter (CMS-HCC)': 741,
#   'Fatigue': 742,
#   'Abdominal lymphadenopathy': 743,
#   'Solar keratosis': 744,
#   'Hydronephrosis, unspecified hydronephrosis type': 745,
#   'Incomplete abortion with infection': 746,
#   'Multi-infarct dementia, uncomplicated (CMS-HCC)': 747,
#   'Hearing loss of both ears': 748,
#   'Disease of hair and hair follicles': 749,
#   'Malignant neoplasm of hard palate (CMS-HCC)': 750,
#   'Duodenum injury, initial encounter': 751,
#   'Status post amputation of lesser toe of right foot (CMS-HCC)': 752,
#   'Venous (peripheral) insufficiency': 753,
#   'Ovarian cyst affecting pregnancy in third trimester, antepartum': 754,
#   'Mycobacterium avium complex (CMS-HCC)': 755,
#   'Rhegmatogenous retinal detachment of left eye': 756,
#   'Deep venous thrombosis (DVT) of left peroneal vein (CMS-HCC)': 757,
#   'History of cone biopsy of cervix': 758,
#   'Acute mesenteric ischemia (CMS-HCC)': 759,
#   'Diaphragmatic hernia with obstruction, without gangrene': 760,
#   'Mild cannabis use disorder': 761,
#   'Solitary pulmonary nodule': 762,
#   'Inflamed internal hemorrhoid': 763,
#   'Ptosis of eyelid, right': 764,
#   'Cicatricial lagophthalmos left upper eyelid': 765,
#   'Right lower quadrant abdominal mass': 766,
#   'Infection of right foot': 767,
#   'Colonic fistula': 768,
#   'Menopause': 769,
#   'Urinary tract infection symptoms': 770,
#   'Scrotal trauma': 771,
#   'Thoracoabdominal aortic aneurysm': 772,
#   'Closed displaced fracture of left pubis (CMS-HCC)': 773,
#   'History of artificial lens replacement': 774,
#   'Infection due to Norovirus species': 775,
#   'Type 2 diabetes mellitus with diabetic mononeuropathy (CMS-HCC)': 776,
#   'Post-transplant diabetes mellitus (CMS-HCC)': 777,
#   'Lymphoma of intestine (CMS-HCC)': 778,
#   'Metastatic renal cell carcinoma to bone (CMS-HCC)': 779,
#   'Rheumatoid arthritis involving both feet (CMS-HCC)': 780,
#   'Blood tests for routine general physical examination': 781,
#   'Disorder of right ventricle of heart': 782,
#   'Mild carpal tunnel syndrome of right wrist': 783,
#   'Desire for pregnancy': 784,
#   'IUFD at less than 20 weeks of gestation': 785,
#   'Hemiplegia, unspecified affecting right dominant side (CMS-HCC)': 786,
#   'Cancer of lip': 787,
#   'Amputation of finger and thumb of right hand, initial encounter': 788,
#   'Episodic atrial fibrillation (CMS-HCC)': 789,
#   'Partial traumatic amputation of right index finger through phalanx, initial encounter': 790,
#   'Adverse effect of penicillamine, sequela': 791,
#   'Problem with dialysis shunt (CMS-HCC)': 792,
#   'Nondisplaced fracture of right radial styloid process, initial encounter for closed fracture': 793,
#   'Laceration of flexor muscle, fascia and tendon of right middle finger at wrist and hand level, initial encounter': 794,
#   'Left elbow pain': 795,
#   'Acute embolism and thrombosis of deep vein of lower extremity, unspecified laterality (CMS-HCC)': 796,
#   'Closed dislocation cervical spine': 797,
#   'Hx of squamous cell carcinoma': 798,
#   'Malignant astrocytoma of temporal lobe (CMS-HCC)': 799,
#   'Neoplasm of uncertain behavior of left renal pelvis': 800,
#   'Abdominal pain, unspecified location': 801,
#   'S/P BKA (below knee amputation), right (CMS-HCC)': 802,
#   'Duodenal adenocarcinoma (CMS-HCC)': 803,
#   'Squamous cell carcinoma of unknown origin': 804,
#   'Stimulant abuse (CMS-HCC)': 805,
#   'Wound of buttock, left, initial encounter': 806,
#   'Apert syndrome': 807,
#   'Spondylosis of cervical spine': 808,
#   'Genu varum of right lower extremity': 809,
#   'Medically complex patient': 810,
#   'Soft tissue abscess': 811,
#   'Laceration of eye region': 812,
#   'Side pain': 813,
#   'ASCUS of cervix with negative high risk HPV': 814,
#   'Herpes simplex type II infection': 815,
#   'Chronic angle-closure glaucoma of eye, right, stage unspecified': 816,
#   'S/P bladder repair': 817,
#   'Stable branch retinal vein occlusion of right eye': 818,
#   'Shoulder arthritis': 819,
#   'Hammertoe': 820,
#   'Femoral hernia': 821,
#   'Food sticks on swallowing': 822,
#   'Abnormal levels of other serum enzymes': 823,
#   'Fracture of left radius': 824,
#   'Benign neoplasm of right orbit': 825,
#   'Colon cancer metastasized to mesenteric lymph nodes (CMS-HCC)': 826,
#   'Congenital stenosis of left pulmonary artery': 827,
#   'Chronic angle-closure glaucoma of both eyes, mild stage': 828,
#   'Pleural abscess (CMS-HCC)': 829,
#   'Recurrent respiratory infection': 830,
#   'Infection of prosthetic right knee joint (CMS-HCC)': 831,
#   'Meibomian gland dysfunction (MGD)': 832,
#   'CML (chronic myeloid leukemia) (CMS-HCC)': 833,
#   'Cubital tunnel syndrome on left': 834,
#   'Malignant neoplasm of left lower eyelid': 835,
#   'Injury of globe of eye, left, subsequent encounter': 836,
#   'Pain of right hip': 837,
#   'Mass of brain': 838,
#   'History of gastric polyp': 839,
#   'Lower limb ulcer (CMS-HCC)': 840,
#   'Minimally conscious state with high-level behavioral responses (CMS-HCC)': 841,
#   'History of left ventricular assist device (CMS-HCC)': 842,
#   'Closed displaced oblique fracture of shaft of left tibia, initial encounter': 843,
#   'Neuroblastoma, olfactory (CMS-HCC)': 844,
#   'Multiple closed fractures of metatarsal bone of left foot': 845,
#   'Ageusia': 846,
#   'Drug-induced chronic gout of right ankle': 847,
#   'Burn of foot, deep third degree, right, subsequent encounter': 848,
#   'Fluency disorder associated with underlying disease': 849,
#   'Homeless': 850,
#   'Multiple exostoses': 851,
#   'Insufficiency of tear film of left eye': 852,
#   'Acute suppurative tonsillitis': 853,
#   'Basal cell carcinoma (BCC) of back': 854,
#   'Abrasion, leg w/ infection': 855,
#   'Borderline glaucoma, bilateral': 856,
#   'Femur fracture (CMS-HCC)': 857,
#   'History of right cataract extraction': 858,
#   'Pressure injury of right hip, unstageable (CMS-HCC)': 859,
#   'Encounter to determine fetal viability of pregnancy, single or unspecified fetus': 860,
#   'Family history of GI tract cancer': 861,
#   'Sympathotonic orthostatic hypotension': 862,
#   'Dyslipidemia, goal to be determined': 863,
#   'Peritoneal dialysis catheter in place (CMS-HCC)': 864,
#   'L5 vertebral fracture (CMS-HCC)': 865,
#   'Acute osteomyelitis of left hand (CMS-HCC)': 866,
#   'Swelling of left lower extremity': 867,
#   'At risk of seizures': 868,
#   'Extreme hyperopia': 869,
#   'Perioperative pain': 870,
#   'Cervical discitis': 871,
#   'Peripheral drusen of both eyes': 872,
#   'Chronic osteomyelitis of left ulna with draining sinus (CMS-HCC)': 873,
#   'Personal history of systemic lupus erythematosus (SLE) (CMS-HCC)': 874,
#   'Burn of right lower extremity, third degree, sequela': 875,
#   'Bronchial fistula (CMS-HCC)': 876,
#   '3rd degree burn of arm': 877,
#   'Colon necrosis (CMS-HCC)': 878,
#   'Other type III open fracture of distal end of left femur with routine healing, subsequent encounter': 879,
#   'Acute heart failure, unspecified heart failure type (CMS-HCC)': 880,
#   'Cerebral aneurysm, nonruptured': 881,
#   'Psychosis, unspecified psychosis type (CMS-HCC)': 882,
#   'Oral mucosal lesion': 883,
#   'Pes planovalgus': 884,
#   'Decubitus ulcer of ischial area, left, stage II (CMS-HCC)': 885,
#   'History of pituitary surgery': 886,
#   'Hemispheric central retinal vein occlusion (CRVO) of right eye': 887,
#   'Abscess of left lower extremity excluding foot': 888,
#   'Lymphoma of extranodal site excluding spleen and other solid organs, unspecified lymphoma type (CMS-HCC)': 889,
#   'Status post placement of cardiac pacemaker': 890,
#   'Osteoarthritis of shoulders, bilateral': 891,
#   'Internal device, implant, or graft infection or inflammation, sequela': 892,
#   'Abnormal neurological exam': 893,
#   'Burn (any degree) involving 50-59 percent of body surface with third degree burn of 10-19% (CMS-HCC)': 894,
#   'Cellulitis of right forearm': 895,
#   'Alcohol use disorder, severe, in sustained remission (CMS-HCC)': 896,
#   'Shoulder pain, unspecified chronicity, unspecified laterality': 897,
#   'Heavy alcohol use': 898,
#   'Ceruminosis, right': 899,
#   'Congenital megaloureter': 900,
#   'Pneumoperitoneum of unknown etiology': 901,
#   'Bipolar affective disorder, current episode severe (CMS-HCC)': 902,
#   'History of back surgery': 903,
#   'Gestational diabetes mellitus, antepartum': 904,
#   'Vitamin B 12 deficiency': 905,
#   'Degenerative arthritis of left ankle': 906,
#   'Chronic bilateral low back pain, unspecified whether sciatica present': 907,
#   'Postpartum depression': 908,
#   'Hematoma of sacrum': 909,
#   'Degloving injury of right upper extremity, subsequent encounter': 910,
#   'Presence of arteriovenous fistula for hemodialysis, primary (CMS-HCC)': 911,
#   'Pneumonia of both lungs due to Pneumocystis jirovecii, unspecified part of lung (CMS-HCC)': 912,
#   'Advanced diabetic retinal disease with proliferative retinopathy and macular edema associated with type 1 diabetes mellitus (CMS-HCC)': 913,
#   'Postsurgical aortocoronary bypass status': 914,
#   'Chronic mitral valve regurgitation': 915,
#   'Cardiac asthma (CMS-HCC)': 916,
#   'Bipolar affective disorder, depressed (CMS-HCC)': 917,
#   'Complete traumatic amputation of left ear': 918,
#   'Closed fracture distal radius and ulna, left, with routine healing, subsequent encounter': 919,
#   'Hemisensory loss': 920,
#   'Macroprolactinoma (CMS-HCC)': 921,
#   'Mechanical complication of ocular lens prosthesis': 922,
#   'Urethral cancer (CMS-HCC)': 923,
#   'Fracture, tibia and fibula, shaft, left, open type III, with routine healing, subsequent encounter': 924,
#   'Inflammatory bowel arthritis': 925,
#   'Kidney cancer, primary, with metastasis from kidney to other site, right (CMS-HCC)': 926,
#   'Encounter for prophylactic measures, unspecified': 927,
#   'Hx of laminectomy': 928,
#   'Benign neoplasm of mandible': 929,
#   'Diabetes mellitus without complication (CMS-HCC)': 930,
#   'Localized swelling on left hand': 931,
#   'Nose septum deviation': 932,
#   'Acute osteomyelitis of phalanx of right foot (CMS-HCC)': 933,
#   'Wound of lower extremity': 934,
#   'History of ventricular fibrillation': 935,
#   'Seizure (CMS-HCC)': 936,
#   'History of anemia': 937,
#   'Family history of malignant neoplasm of stomach': 938,
#   'Status post abdominoplasty': 939,
#   'Keratoconus of right eye': 940,
#   'Gluteal abscess': 941,
#   'Drug-induced skin rash': 942,
#   'Laceration of right hand with complication, initial encounter': 943,
#   'Crushing injury of finger of left hand': 944,
#   'Episode of gagging': 945,
#   'Chronic ischemic heart disease, unspecified': 946,
#   'Subretinal hemorrhage of right eye': 947,
#   'Malignant neoplasm of male breast (CMS-HCC)': 948,
#   'History of amphetamine dependence/abuse (CMS-HCC)': 949,
#   'Hyperostosis': 950,
#   'Cellulitis, perineum': 951,
#   'Class 1 obesity with serious comorbidity in adult': 952,
#   'Displaced bicondylar fracture of left tibia, initial encounter for closed fracture': 953,
#   'Burn of thigh, deep third degree with body part loss, right, initial encounter': 954,
#   'Closed fracture of multiple ribs of right side with nonunion': 955,
#   'Rectum cancer (CMS-HCC)': 956,
#   'Rumination syndrome of ingested food in adult': 957,
#   'Localized osteoarthritis of knees, bilateral': 958,
#   'PICC (peripherally inserted central catheter) removal': 959,
#   'Baclofen overdose': 960,
#   'Arthropathy of left sacroiliac joint': 961,
#   'Pain of metastatic malignancy': 962,
#   'Meibomianitis of right eye': 963,
#   "Crohn's disease of large intestine with complication (CMS-HCC)": 964,
#   'Malignant neoplasm of parapharyngeal space (CMS-HCC)': 965,
#   'S/P knee surgery': 966,
#   'Bilateral hip bursitis': 967,
#   'Left anterior fascicular block (LAFB)': 968,
#   'Diverticulitis of large intestine without bleeding': 969,
#   'Open wound of heel': 970,
#   'Unspecified disorder of menstruation and other abnormal bleeding from female genital tract': 971,
#   'Endoleak post (EVAR) endovascular aneurysm repair (CMS-HCC)': 972,
#   'Congenital pulmonary airway malformation (CPAM)': 973,
#   'Closed right calcaneal fracture': 974,
#   'Open extensive facial fractures, initial encounter (CMS-HCC)': 975,
#   'Metastasis from colon cancer (CMS-HCC)': 976,
#   'Hx of falling': 977,
#   "Crohn's disease of colon with intestinal obstruction (CMS-HCC)": 978,
#   'Azoospermia due to obstruction': 979,
#   'Squamous cell carcinoma in situ (SCCIS) of skin of nose': 980,
#   'Subarachnoid hematoma': 981,
#   'Oligodendroglioma (CMS-HCC)': 982,
#   'Open wound of right foot': 983,
#   'Diastolic congestive heart failure, NYHA class 2 (CMS-HCC)': 984,
#   'Personal history of noncompliance with medical treatment': 985,
#   'Red skin': 986,
#   'Long term current use of amiodarone': 987,
#   'Acute urinary obstruction': 988,
#   'Polyp of anal verge': 989,
#   'Acquired hallux rigidus': 990,
#   'Subconjunctival hemorrhage': 991,
#   'Abnormal CT of liver': 992,
#   'Carotid stenosis, asymptomatic': 993,
#   'Prurigo': 994,
#   'Posterior staphyloma, right': 995,
#   'Primary immunodeficiency disorder': 996,
#   'Underweight': 997,
#   'Atrial fibrillation, new onset (CMS-HCC)': 998,
#   'Tracheal granulation': 999,
#   ...}}

# %%
len(patient_history_encoding['dx_name'])
# Out:
# 59056

# %% [markdown]
# # Cleaning patient information
# Here The columns ICU_ADMIN_FLAG, SEX, PRIMARY_ANES_TYPE_NM, PATIENT_CLASS_GROUP, DISCH_DISP_C, ASA_RATING_C are encoded

# %%
patient_information_encoding = {}
cols_to_encode = ['ICU_ADMIN_FLAG','SEX','PRIMARY_ANES_TYPE_NM','PATIENT_CLASS_GROUP'] # DISCH_DISP
data = pl.read_csv('EPIC_EMR/patient_information.csv',dtypes={})
data = data.unique()
data = data.with_columns(pl.col('DISCH_DISP_C').cast(pl.UInt64),pl.col('ASA_RATING_C').cast(pl.UInt64))

two_columns_encoding = [('DISCH_DISP','DISCH_DISP_C'),('ASA_RATING','ASA_RATING_C')]

# %%
data
# Out:
# shape: (64_364, 23)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ LOG_ID    ┆ MRN       ┆ DISCH_DIS ┆ DISCH_DIS ┆ … ┆ IN_OR_DTT ┆ OUT_OR_DT ┆ AN_START_ ┆ AN_STOP_ │
# │ ---       ┆ ---       ┆ P_C       ┆ P         ┆   ┆ M         ┆ TM        ┆ DATETIME  ┆ DATETIME │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆ u64       ┆ str       ┆   ┆ str       ┆ str       ┆ str       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 8778901ee ┆ 2e34dcb07 ┆ 15        ┆ Home      ┆ … ┆ 3/17/20   ┆ 3/17/20   ┆ 3/17/20   ┆ 3/17/20  │
# │ b9b6166   ┆ 91b8c0d   ┆           ┆ Routine   ┆   ┆ 8:18      ┆ 10:19     ┆ 8:18      ┆ 10:22    │
# │ b1df0a3b9 ┆ 1a479b8ba ┆ 6         ┆ Skilled   ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 037bd60   ┆ d216511   ┆           ┆ Nursing   ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ Facility  ┆   ┆           ┆           ┆           ┆          │
# │ 987faad1d ┆ c3ce84c4f ┆ 100       ┆ Rehab     ┆ … ┆ 1/13/20   ┆ 1/13/20   ┆ 1/13/20   ┆ 1/13/20  │
# │ f9faadc   ┆ 165f902   ┆           ┆ Facility  ┆   ┆ 7:26      ┆ 13:25     ┆ 7:26      ┆ 13:31    │
# │           ┆           ┆           ┆ (this     ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ hospital) ┆   ┆           ┆           ┆           ┆          │
# │ 9be3203bb ┆ b167a720b ┆ 15        ┆ Home      ┆ … ┆ 3/1/19    ┆ 3/1/19    ┆ 3/1/19    ┆ 3/1/19   │
# │ ac4d29e   ┆ f50bf49   ┆           ┆ Routine   ┆   ┆ 7:20      ┆ 13:18     ┆ 7:18      ┆ 13:29    │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ b28243738 ┆ 068e7bc83 ┆ 20        ┆ Home Heal ┆ … ┆ 10/19/20  ┆ 10/19/20  ┆ 10/19/20  ┆ 10/19/20 │
# │ 79ec86f   ┆ 4d7b6e9   ┆           ┆ thcare IP ┆   ┆ 7:11      ┆ 9:22      ┆ 7:11      ┆ 9:29     │
# │           ┆           ┆           ┆ Admit     ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ Related   ┆   ┆           ┆           ┆           ┆          │
# │ 723bd7f01 ┆ 75f181962 ┆ 15        ┆ Home      ┆ … ┆ 7/1/21    ┆ 7/1/21    ┆ 7/1/21    ┆ 7/1/21   │
# │ 5359502   ┆ 863431d   ┆           ┆ Routine   ┆   ┆ 19:09     ┆ 22:27     ┆ 19:08     ┆ 22:33    │
# │ 03a3dd66b ┆ d1f0f2b2f ┆ 15        ┆ Home      ┆ … ┆ 8/29/22   ┆ 8/29/22   ┆ 8/29/22   ┆ 8/29/22  │
# │ 5085cea   ┆ fff298d   ┆           ┆ Routine   ┆   ┆ 14:01     ┆ 17:37     ┆ 14:01     ┆ 17:38    │
# │ 4e9a00025 ┆ 3f4d806a9 ┆ 13        ┆ Against   ┆ … ┆ 8/3/22    ┆ 8/3/22    ┆ 8/3/22    ┆ 8/3/22   │
# │ 443f41b   ┆ 527ad5f   ┆           ┆ Medical   ┆   ┆ 17:30     ┆ 22:01     ┆ 17:27     ┆ 22:10    │
# │           ┆           ┆           ┆ Advice    ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
for col_1,col_2 in two_columns_encoding:
    patient_information_encoding[col_1+'___'+col_2] = encode_two_columns(data,col_1,col_2)

for col in cols_to_encode:
    data, patient_information_encoding[col] = encode_column_and_replace(data,col)

# %%
data.null_count()
# Out:
# shape: (1, 27)
# ┌────────┬─────┬──────────────┬────────────┬───┬───────────────────┬─────────────┬──────────────────┬──────────────────┐
# │ LOG_ID ┆ MRN ┆ DISCH_DISP_C ┆ DISCH_DISP ┆ … ┆ ICU_ADMIN_FLAG_en ┆ SEX_encoded ┆ PRIMARY_ANES_TYP ┆ PATIENT_CLASS_GR │
# │ ---    ┆ --- ┆ ---          ┆ ---        ┆   ┆ coded             ┆ ---         ┆ E_NM_encoded     ┆ OUP_encoded      │
# │ u32    ┆ u32 ┆ u32          ┆ u32        ┆   ┆ ---               ┆ u32         ┆ ---              ┆ ---              │
# │        ┆     ┆              ┆            ┆   ┆ u32               ┆             ┆ u32              ┆ u32              │
# ╞════════╪═════╪══════════════╪════════════╪═══╪═══════════════════╪═════════════╪══════════════════╪══════════════════╡
# │ 0      ┆ 0   ┆ 7            ┆ 7          ┆ … ┆ 0                 ┆ 0           ┆ 0                ┆ 0                │
# └────────┴─────┴──────────────┴────────────┴───┴───────────────────┴─────────────┴──────────────────┴──────────────────┘

# %%
data, patient_information_encoding['DISCH_DISP'] = encode_column_and_replace(data,'DISCH_DISP',patient_information_encoding['DISCH_DISP___DISCH_DISP_C'])
data, patient_information_encoding['ASA_RATING'] = encode_column_and_replace(data,'ASA_RATING',patient_information_encoding['ASA_RATING___ASA_RATING_C'])

# %%
data.null_count()
# Out:
# shape: (1, 29)
# ┌────────┬─────┬─────────────┬────────────┬───┬─────────────┬────────────┬────────────┬────────────┐
# │ LOG_ID ┆ MRN ┆ DISCH_DISP_ ┆ DISCH_DISP ┆ … ┆ PRIMARY_ANE ┆ PATIENT_CL ┆ DISCH_DISP ┆ ASA_RATING │
# │ ---    ┆ --- ┆ C           ┆ ---        ┆   ┆ S_TYPE_NM_e ┆ ASS_GROUP_ ┆ _encoded   ┆ _encoded   │
# │ u32    ┆ u32 ┆ ---         ┆ u32        ┆   ┆ ncoded      ┆ encoded    ┆ ---        ┆ ---        │
# │        ┆     ┆ u32         ┆            ┆   ┆ ---         ┆ ---        ┆ u32        ┆ u32        │
# │        ┆     ┆             ┆            ┆   ┆ u32         ┆ u32        ┆            ┆            │
# ╞════════╪═════╪═════════════╪════════════╪═══╪═════════════╪════════════╪════════════╪════════════╡
# │ 0      ┆ 0   ┆ 7           ┆ 7          ┆ … ┆ 0           ┆ 0          ┆ 7          ┆ 6811       │
# └────────┴─────┴─────────────┴────────────┴───┴─────────────┴────────────┴────────────┴────────────┘

# %%
data.head()
# Out:
# shape: (5, 29)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ LOG_ID    ┆ MRN       ┆ DISCH_DIS ┆ DISCH_DIS ┆ … ┆ PRIMARY_A ┆ PATIENT_C ┆ DISCH_DIS ┆ ASA_RATI │
# │ ---       ┆ ---       ┆ P_C       ┆ P         ┆   ┆ NES_TYPE_ ┆ LASS_GROU ┆ P_encoded ┆ NG_encod │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ NM_encode ┆ P_encoded ┆ ---       ┆ ed       │
# │           ┆           ┆ u64       ┆ str       ┆   ┆ d         ┆ ---       ┆ u64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ ---       ┆ u64       ┆           ┆ u64      │
# │           ┆           ┆           ┆           ┆   ┆ u64       ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 8778901ee ┆ 2e34dcb07 ┆ 15        ┆ Home      ┆ … ┆ 11        ┆ 1         ┆ 15        ┆ 2        │
# │ b9b6166   ┆ 91b8c0d   ┆           ┆ Routine   ┆   ┆           ┆           ┆           ┆          │
# │ b1df0a3b9 ┆ 1a479b8ba ┆ 6         ┆ Skilled   ┆ … ┆ 11        ┆ 0         ┆ 6         ┆ 3        │
# │ 037bd60   ┆ d216511   ┆           ┆ Nursing   ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ Facility  ┆   ┆           ┆           ┆           ┆          │
# │ 987faad1d ┆ c3ce84c4f ┆ 100       ┆ Rehab     ┆ … ┆ 11        ┆ 0         ┆ 100       ┆ 3        │
# │ f9faadc   ┆ 165f902   ┆           ┆ Facility  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ (this     ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ hospital) ┆   ┆           ┆           ┆           ┆          │
# │ 9be3203bb ┆ b167a720b ┆ 15        ┆ Home      ┆ … ┆ 11        ┆ 1         ┆ 15        ┆ 1        │
# │ ac4d29e   ┆ f50bf49   ┆           ┆ Routine   ┆   ┆           ┆           ┆           ┆          │
# │ f0d16bb8e ┆ 95d54ee9f ┆ 15        ┆ Home      ┆ … ┆ 11        ┆ 1         ┆ 15        ┆ 2        │
# │ 593218e   ┆ 5abfab3   ┆           ┆ Routine   ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
patient_information_encoding
# Out:
# {'DISCH_DISP___DISCH_DISP_C': {'Hospice Home': 22,
#   'Board and Care': 103,
#   None: None,
#   "Cancer Ctr/Children's Hospital": 18,
#   'Temporary Living': 108,
#   'Jail/Prison': 10,
#   'Federal Hospital': 11,
#   'Other Healthcare Not Defined in this List': 70,
#   'Independent Living': 106,
#   'Acute Care Facility (this hospital)': 8,
#   'Against Medical Advice': 13,
#   'Recuperative Care': 105,
#   'Home Healthcare Outside 3 Days': 21,
#   'Psychiatric Facility (not this hospital)': 9,
#   'Intermediate/Residential Care Facility': 5,
#   'Designated Disaster Alternate Care Site': 69,
#   'Hospice Facility': 16,
#   'Shelter': 102,
#   'Coroner': 23,
#   'Skilled Nursing w Planned Readmit': 83,
#   'Home Routine': 15,
#   'Home Healthcare Outpatient Related': 109,
#   'Home Health w Planned Readmit': 86,
#   'Rehab Facility (this hospital)': 100,
#   'Acute Care Facility (not this hospital)': 26,
#   'Home Healthcare IP Admit Related': 20,
#   'Expired': 3,
#   'Psychiatric Facility (this hospital)': 19,
#   'Sub-Acute Care Facility': 107,
#   'Critical Access Hospital': 66,
#   'Skilled Nursing Facility': 6,
#   'Long Term Care Facility': 30,
#   'Room and Board': 104,
#   'Rehab Facility (not this hospital)': 4,
#   'Federal Hospital w Planned Readmit': 88,
#   'Intermediate/Residential Care w Planned Readmit': 84,
#   'Designated Disaster Alternative Care Site': 69},
#  'ASA_RATING___ASA_RATING_C': {None: None,
#   'Severe Systemic Disease': 3,
#   'Incapacitating Disease': 4,
#   'Healthy': 1,
#   'Brain Dead': 6,
#   'Moribund': 5,
#   'Mild Systemic Disease': 2},
#  'ICU_ADMIN_FLAG': {'No': 0, 'Yes': 1},
#  'SEX': {'Female': 0, 'Unknown': 1, 'Male': 2},
#  'PRIMARY_ANES_TYPE_NM': {'Spinal': 0,
#   'Topical': 1,
#   'Local': 2,
#   None: 3,
#   'Monitored Anesthesia Care (MAC)': 4,
#   'Moderate Sedation - by non-anesthesia staff only': 5,
#   'Epidural': 6,
#   'Regional': 7,
#   'Choice Per Patient on Day of Surgery': 8,
#   'None': 9,
#   'Monitored Anesthesia Care (MAC) ': 10,
#   'General': 11},
#  'PATIENT_CLASS_GROUP': {'Inpatient': 0, 'Outpatient': 1},
#  'DISCH_DISP': {'Hospice Home': 22,
#   'Board and Care': 103,
#   None: None,
#   "Cancer Ctr/Children's Hospital": 18,
#   'Temporary Living': 108,
#   'Jail/Prison': 10,
#   'Federal Hospital': 11,
#   'Other Healthcare Not Defined in this List': 70,
#   'Independent Living': 106,
#   'Acute Care Facility (this hospital)': 8,
#   'Against Medical Advice': 13,
#   'Recuperative Care': 105,
#   'Home Healthcare Outside 3 Days': 21,
#   'Psychiatric Facility (not this hospital)': 9,
#   'Intermediate/Residential Care Facility': 5,
#   'Designated Disaster Alternate Care Site': 69,
#   'Hospice Facility': 16,
#   'Shelter': 102,
#   'Coroner': 23,
#   'Skilled Nursing w Planned Readmit': 83,
#   'Home Routine': 15,
#   'Home Healthcare Outpatient Related': 109,
#   'Home Health w Planned Readmit': 86,
#   'Rehab Facility (this hospital)': 100,
#   'Acute Care Facility (not this hospital)': 26,
#   'Home Healthcare IP Admit Related': 20,
#   'Expired': 3,
#   'Psychiatric Facility (this hospital)': 19,
#   'Sub-Acute Care Facility': 107,
#   'Critical Access Hospital': 66,
#   'Skilled Nursing Facility': 6,
#   'Long Term Care Facility': 30,
#   'Room and Board': 104,
#   'Rehab Facility (not this hospital)': 4,
#   'Federal Hospital w Planned Readmit': 88,
#   'Intermediate/Residential Care w Planned Readmit': 84,
#   'Designated Disaster Alternative Care Site': 69},
#  'ASA_RATING': {None: None,
#   'Severe Systemic Disease': 3,
#   'Incapacitating Disease': 4,
#   'Healthy': 1,
#   'Brain Dead': 6,
#   'Moribund': 5,
#   'Mild Systemic Disease': 2}}

# %% [markdown]
# The Height is fiven in feet'inch metric. We convert this into centimeters.

# %%
data = data.with_columns(pl.col('HEIGHT').str.split(by="'").map_elements(lambda x: float(x[0])*30.48  + float(x[1])*2.54).alias('HEIGHT_IN_CM'))

# %%
data.head()
# Out:
# shape: (5, 30)
# ┌──────────────┬──────────────┬──────────────┬─────────────┬───┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ LOG_ID       ┆ MRN          ┆ DISCH_DISP_C ┆ DISCH_DISP  ┆ … ┆ PATIENT_CLA ┆ DISCH_DISP_ ┆ ASA_RATING_ ┆ HEIGHT_IN_C │
# │ ---          ┆ ---          ┆ ---          ┆ ---         ┆   ┆ SS_GROUP_en ┆ encoded     ┆ encoded     ┆ M           │
# │ str          ┆ str          ┆ u64          ┆ str         ┆   ┆ coded       ┆ ---         ┆ ---         ┆ ---         │
# │              ┆              ┆              ┆             ┆   ┆ ---         ┆ u64         ┆ u64         ┆ f64         │
# │              ┆              ┆              ┆             ┆   ┆ u64         ┆             ┆             ┆             │
# ╞══════════════╪══════════════╪══════════════╪═════════════╪═══╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ b1df0a3b9037 ┆ 1a479b8bad21 ┆ 6            ┆ Skilled     ┆ … ┆ 0           ┆ 6           ┆ 3           ┆ 170.18      │
# │ bd60         ┆ 6511         ┆              ┆ Nursing     ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆              ┆ Facility    ┆   ┆             ┆             ┆             ┆             │
# │ 3a6111f16e86 ┆ 0631bc4823cb ┆ 15           ┆ Home        ┆ … ┆ 1           ┆ 15          ┆ 3           ┆ 170.18      │
# │ a6e5         ┆ 2d5c         ┆              ┆ Routine     ┆   ┆             ┆             ┆             ┆             │
# │ 6934cc3d1f5f ┆ a6587bf8204e ┆ 15           ┆ Home        ┆ … ┆ 1           ┆ 15          ┆ 2           ┆ 157.48      │
# │ b7ae         ┆ 7402         ┆              ┆ Routine     ┆   ┆             ┆             ┆             ┆             │
# │ cd9d02c27c53 ┆ 124309aae78f ┆ 15           ┆ Home        ┆ … ┆ 1           ┆ 15          ┆ 1           ┆ 185.42      │
# │ faa5         ┆ 4a57         ┆              ┆ Routine     ┆   ┆             ┆             ┆             ┆             │
# │ 4acd62ee4370 ┆ 2be182dda74a ┆ 15           ┆ Home        ┆ … ┆ 1           ┆ 15          ┆ 2           ┆ null        │
# │ cda2         ┆ 3d73         ┆              ┆ Routine     ┆   ┆             ┆             ┆             ┆             │
# └──────────────┴──────────────┴──────────────┴─────────────┴───┴─────────────┴─────────────┴─────────────┴─────────────┘

# %%
data.columns
# Out:
# ['LOG_ID',
#  'MRN',
#  'DISCH_DISP_C',
#  'DISCH_DISP',
#  'HOSP_ADMSN_TIME',
#  'HOSP_DISCH_TIME',
#  'LOS',
#  'ICU_ADMIN_FLAG',
#  'SURGERY_DATE',
#  'BIRTH_DATE',
#  'HEIGHT',
#  'WEIGHT',
#  'SEX',
#  'PRIMARY_ANES_TYPE_NM',
#  'ASA_RATING_C',
#  'ASA_RATING',
#  'PATIENT_CLASS_GROUP',
#  'PATIENT_CLASS_NM',
#  'PRIMARY_PROCEDURE_NM',
#  'IN_OR_DTTM',
#  'OUT_OR_DTTM',
#  'AN_START_DATETIME',
#  'AN_STOP_DATETIME',
#  'ICU_ADMIN_FLAG_encoded',
#  'SEX_encoded',
#  'PRIMARY_ANES_TYPE_NM_encoded',
#  'PATIENT_CLASS_GROUP_encoded',
#  'DISCH_DISP_encoded',
#  'ASA_RATING_encoded',
#  'HEIGHT_IN_CM']

# %% [markdown]
# We filter the columns that provide useful information for our analysis and models.

# %%
columns_needed=[
    'LOG_ID',
    'MRN',
 'HOSP_ADMSN_TIME',
 'HOSP_DISCH_TIME',
 'LOS',
 'SURGERY_DATE',
 'BIRTH_DATE',
 'WEIGHT',
 'IN_OR_DTTM',
 'OUT_OR_DTTM',
 'AN_START_DATETIME',
 'AN_STOP_DATETIME',
 'ICU_ADMIN_FLAG_encoded',
 'SEX_encoded',
 'PRIMARY_ANES_TYPE_NM_encoded',
 'PATIENT_CLASS_GROUP_encoded',
 'DISCH_DISP_encoded',
 'ASA_RATING_encoded',
 'HEIGHT_IN_CM']

# %%
len(columns_needed)
# Out:
# 19

# %%
data = data.select(columns_needed)
print(data.shape)
data.write_csv('EPIC_EMR_cleaned/patient_information_cleaned.csv')
# Out:
# (64364, 19)

# %% [markdown]
# # Cleaning patient lab data

# %% [markdown]
# This is a very large csv file with the size of 3GB. This file contains lab samples of every patient. The column 'Abnormal Flag' is created by lab faculty based on all the other attributes of the patient, which means it can summarise all the other attributes. Thus, we can omit rest of the columns.

# %%
patient_lab_encoding = {}
cols_to_encode = ['Abnormal Flag'] # DISCH_DISP
data = pl.read_csv('EPIC_EMR/patient_labs.csv',dtypes={})
data = data.unique()

# %%
data.head()
# Out:
# shape: (5, 10)
# ┌───────────────────┬───────────────────┬─────────────┬──────────┬───┬─────────────┬───────────┬──────────┬────────────┐
# │ LOG_ID            ┆ MRN               ┆ ENC_TYPE_NM ┆ Lab Code ┆ … ┆ Measurement ┆ Reference ┆ Abnormal ┆ Collection │
# │ ---               ┆ ---               ┆ ---         ┆ ---      ┆   ┆ Units       ┆ Range     ┆ Flag     ┆ Datetime   │
# │ str               ┆ str               ┆ str         ┆ str      ┆   ┆ ---         ┆ ---       ┆ ---      ┆ ---        │
# │                   ┆                   ┆             ┆          ┆   ┆ str         ┆ str       ┆ str      ┆ str        │
# ╞═══════════════════╪═══════════════════╪═════════════╪══════════╪═══╪═════════════╪═══════════╪══════════╪════════════╡
# │ 0da0bc3be9423462  ┆ 1bb09d5761661c7d  ┆ Hospital    ┆ 11475-1  ┆ … ┆ Unknown     ┆ Unknown   ┆ N        ┆ 2021-01-14 │
# │                   ┆                   ┆ Encounter   ┆          ┆   ┆             ┆           ┆          ┆ 20:58:00   │
# │ 3ab8e6344cc9f954  ┆ 559c869f9d7db8ee  ┆ Hospital    ┆ 1994-3   ┆ … ┆ mmol/L      ┆ 1.13-1.32 ┆ N        ┆ 2020-03-10 │
# │                   ┆                   ┆ Encounter   ┆          ┆   ┆             ┆           ┆          ┆ 10:31:00   │
# │ 3ab8e6344cc9f954  ┆ 559c869f9d7db8ee  ┆ Hospital    ┆ 2028-9   ┆ … ┆ mmol/L      ┆ 21-31     ┆ N        ┆ 2020-03-13 │
# │                   ┆                   ┆ Encounter   ┆          ┆   ┆             ┆           ┆          ┆ 16:41:00   │
# │ 3ab8e6344cc9f954  ┆ 559c869f9d7db8ee  ┆ Hospital    ┆ 2028-9   ┆ … ┆ mmol/L      ┆ 21-31     ┆ N        ┆ 2020-03-16 │
# │                   ┆                   ┆ Encounter   ┆          ┆   ┆             ┆           ┆          ┆ 05:07:00   │
# │ 3ab8e6344cc9f954  ┆ 559c869f9d7db8ee  ┆ Hospital    ┆ 2951-2   ┆ … ┆ mmol/L      ┆ 136-145   ┆ N        ┆ 2020-03-09 │
# │                   ┆                   ┆ Encounter   ┆          ┆   ┆             ┆           ┆          ┆ 05:33:00   │
# └───────────────────┴───────────────────┴─────────────┴──────────┴───┴─────────────┴───────────┴──────────┴────────────┘

# %%
for col in cols_to_encode:
    data, patient_lab_encoding[col] = encode_column_and_replace(data,col)

# %%
data.null_count()
# Out:
# shape: (1, 11)
# ┌────────┬─────┬─────────────┬──────────┬───┬─────────────────┬───────────────┬────────────┬───────────────────────┐
# │ LOG_ID ┆ MRN ┆ ENC_TYPE_NM ┆ Lab Code ┆ … ┆ Reference Range ┆ Abnormal Flag ┆ Collection ┆ Abnormal Flag_encoded │
# │ ---    ┆ --- ┆ ---         ┆ ---      ┆   ┆ ---             ┆ ---           ┆ Datetime   ┆ ---                   │
# │ u32    ┆ u32 ┆ u32         ┆ u32      ┆   ┆ u32             ┆ u32           ┆ ---        ┆ u32                   │
# │        ┆     ┆             ┆          ┆   ┆                 ┆               ┆ u32        ┆                       │
# ╞════════╪═════╪═════════════╪══════════╪═══╪═════════════════╪═══════════════╪════════════╪═══════════════════════╡
# │ 0      ┆ 0   ┆ 0           ┆ 0        ┆ … ┆ 0               ┆ 201566        ┆ 0          ┆ 0                     │
# └────────┴─────┴─────────────┴──────────┴───┴─────────────────┴───────────────┴────────────┴───────────────────────┘

# %%
data.head()
# Out:
# shape: (5, 11)
# ┌───────────────────┬──────────────────┬─────────────┬──────────┬───┬───────────┬──────────┬────────────┬──────────────┐
# │ LOG_ID            ┆ MRN              ┆ ENC_TYPE_NM ┆ Lab Code ┆ … ┆ Reference ┆ Abnormal ┆ Collection ┆ Abnormal     │
# │ ---               ┆ ---              ┆ ---         ┆ ---      ┆   ┆ Range     ┆ Flag     ┆ Datetime   ┆ Flag_encoded │
# │ str               ┆ str              ┆ str         ┆ str      ┆   ┆ ---       ┆ ---      ┆ ---        ┆ ---          │
# │                   ┆                  ┆             ┆          ┆   ┆ str       ┆ str      ┆ str        ┆ u64          │
# ╞═══════════════════╪══════════════════╪═════════════╪══════════╪═══╪═══════════╪══════════╪════════════╪══════════════╡
# │ 0da0bc3be9423462  ┆ 1bb09d5761661c7d ┆ Hospital    ┆ 11475-1  ┆ … ┆ Unknown   ┆ N        ┆ 2021-01-14 ┆ 4            │
# │                   ┆                  ┆ Encounter   ┆          ┆   ┆           ┆          ┆ 20:58:00   ┆              │
# │ 3ab8e6344cc9f954  ┆ 559c869f9d7db8ee ┆ Hospital    ┆ 1994-3   ┆ … ┆ 1.13-1.32 ┆ N        ┆ 2020-03-10 ┆ 4            │
# │                   ┆                  ┆ Encounter   ┆          ┆   ┆           ┆          ┆ 10:31:00   ┆              │
# │ 3ab8e6344cc9f954  ┆ 559c869f9d7db8ee ┆ Hospital    ┆ 2028-9   ┆ … ┆ 21-31     ┆ N        ┆ 2020-03-13 ┆ 4            │
# │                   ┆                  ┆ Encounter   ┆          ┆   ┆           ┆          ┆ 16:41:00   ┆              │
# │ 3ab8e6344cc9f954  ┆ 559c869f9d7db8ee ┆ Hospital    ┆ 2028-9   ┆ … ┆ 21-31     ┆ N        ┆ 2020-03-16 ┆ 4            │
# │                   ┆                  ┆ Encounter   ┆          ┆   ┆           ┆          ┆ 05:07:00   ┆              │
# │ 3ab8e6344cc9f954  ┆ 559c869f9d7db8ee ┆ Hospital    ┆ 2951-2   ┆ … ┆ 136-145   ┆ N        ┆ 2020-03-09 ┆ 4            │
# │                   ┆                  ┆ Encounter   ┆          ┆   ┆           ┆          ┆ 05:33:00   ┆              │
# └───────────────────┴──────────────────┴─────────────┴──────────┴───┴───────────┴──────────┴────────────┴──────────────┘

# %%
columns_needed = ['Abnormal Flag_encoded','Collection Datetime','LOG_ID','MRN']
data = data.select(columns_needed)
print(data.shape)
data.write_csv('EPIC_EMR_cleaned/patient_labs_cleaned.csv')
# Out:
# (29071808, 4)

# %% [markdown]
# # Cleaning patient post op complications

# %% [markdown]
# This Dataset contains the post operative complications observed by the patients. All of the columns provide useful information for our analysis, which must be encoded.

# %%
patient_post_op_encoding = {}
cols_to_encode = ['CONTEXT_NAME','Element_abbr','SMRTDTA_ELEM_VALUE'] 
data = pl.read_csv('EPIC_EMR/patient_post_op_complications.csv',dtypes={})
data = data.unique()

# %%
data.head(35)
# Out:
# shape: (35, 6)
# ┌──────────────────┬──────────────────┬────────────────┬──────────────┬───────────────────────────┬────────────────────┐
# │ LOG_ID           ┆ MRN              ┆ Element_Name   ┆ CONTEXT_NAME ┆ Element_abbr              ┆ SMRTDTA_ELEM_VALUE │
# │ ---              ┆ ---              ┆ ---            ┆ ---          ┆ ---                       ┆ ---                │
# │ str              ┆ str              ┆ str            ┆ str          ┆ str                       ┆ str                │
# ╞══════════════════╪══════════════════╪════════════════╪══════════════╪═══════════════════════════╪════════════════════╡
# │ f730e521222298ed ┆ 2c8c2d76b0ae346a ┆ AN AQI POST-OP ┆ ENCOUNTER    ┆ AN Post-op Complications  ┆ None               │
# │                  ┆                  ┆ COMPLICATIONS  ┆              ┆                           ┆                    │
# │ fc53c06ee2cfe438 ┆ b7a91e623d957d8f ┆ AN AQI POST-OP ┆ ENCOUNTER    ┆ AN Post-op Complications  ┆ None               │
# │                  ┆                  ┆ COMPLICATIONS  ┆              ┆                           ┆                    │
# │ 8a3336d8a4802db4 ┆ aefa5d48bed86687 ┆ AN AQI POST-OP ┆ ENCOUNTER    ┆ AN Post-op Complications  ┆ None               │
# │                  ┆                  ┆ COMPLICATIONS  ┆              ┆                           ┆                    │
# │ a99a2b466b583603 ┆ 16c69fd7b03e8a31 ┆ AN AQI POST-OP ┆ ENCOUNTER    ┆ AN Post-op Complications  ┆ None               │
# │                  ┆                  ┆ COMPLICATIONS  ┆              ┆                           ┆                    │
# │ …                ┆ …                ┆ …              ┆ …            ┆ …                         ┆ …                  │
# │ fb086104b9a8bb61 ┆ e0ff95dcd2f69b3a ┆ AN AQI POST-OP ┆ ENCOUNTER    ┆ AN Post-op Complications  ┆ None               │
# │                  ┆                  ┆ COMPLICATIONS  ┆              ┆                           ┆                    │
# │ 007e4258182e653d ┆ 90a0d343c0bb46d8 ┆ AN AQI POST-OP ┆ ENCOUNTER    ┆ AN Post-op Complications  ┆ None               │
# │                  ┆                  ┆ COMPLICATIONS  ┆              ┆                           ┆                    │
# │ cfa2d4333e063967 ┆ cf954e996f155b70 ┆ AN AQI POST-OP ┆ ENCOUNTER    ┆ AN Post-op Complications  ┆ None               │
# │                  ┆                  ┆ COMPLICATIONS  ┆              ┆                           ┆                    │
# │ 0e70cf4d3103bc9c ┆ 7bc1502ac99488aa ┆ AN AQI POST-OP ┆ ENCOUNTER    ┆ AN Post-op Complications  ┆ None               │
# │                  ┆                  ┆ COMPLICATIONS  ┆              ┆                           ┆                    │
# └──────────────────┴──────────────────┴────────────────┴──────────────┴───────────────────────────┴────────────────────┘

# %%
data = data.with_columns(pl.col('Element_abbr').str.replace(r"AN Post-op Complications",''))
data.head(35)
# Out:
# shape: (35, 6)
# ┌──────────────────┬──────────────────┬────────────────┬──────────────┬──────────────┬────────────────────┐
# │ LOG_ID           ┆ MRN              ┆ Element_Name   ┆ CONTEXT_NAME ┆ Element_abbr ┆ SMRTDTA_ELEM_VALUE │
# │ ---              ┆ ---              ┆ ---            ┆ ---          ┆ ---          ┆ ---                │
# │ str              ┆ str              ┆ str            ┆ str          ┆ str          ┆ str                │
# ╞══════════════════╪══════════════════╪════════════════╪══════════════╪══════════════╪════════════════════╡
# │ f730e521222298ed ┆ 2c8c2d76b0ae346a ┆ AN AQI POST-OP ┆ ENCOUNTER    ┆              ┆ None               │
# │                  ┆                  ┆ COMPLICATIONS  ┆              ┆              ┆                    │
# │ fc53c06ee2cfe438 ┆ b7a91e623d957d8f ┆ AN AQI POST-OP ┆ ENCOUNTER    ┆              ┆ None               │
# │                  ┆                  ┆ COMPLICATIONS  ┆              ┆              ┆                    │
# │ 8a3336d8a4802db4 ┆ aefa5d48bed86687 ┆ AN AQI POST-OP ┆ ENCOUNTER    ┆              ┆ None               │
# │                  ┆                  ┆ COMPLICATIONS  ┆              ┆              ┆                    │
# │ a99a2b466b583603 ┆ 16c69fd7b03e8a31 ┆ AN AQI POST-OP ┆ ENCOUNTER    ┆              ┆ None               │
# │                  ┆                  ┆ COMPLICATIONS  ┆              ┆              ┆                    │
# │ …                ┆ …                ┆ …              ┆ …            ┆ …            ┆ …                  │
# │ fb086104b9a8bb61 ┆ e0ff95dcd2f69b3a ┆ AN AQI POST-OP ┆ ENCOUNTER    ┆              ┆ None               │
# │                  ┆                  ┆ COMPLICATIONS  ┆              ┆              ┆                    │
# │ 007e4258182e653d ┆ 90a0d343c0bb46d8 ┆ AN AQI POST-OP ┆ ENCOUNTER    ┆              ┆ None               │
# │                  ┆                  ┆ COMPLICATIONS  ┆              ┆              ┆                    │
# │ cfa2d4333e063967 ┆ cf954e996f155b70 ┆ AN AQI POST-OP ┆ ENCOUNTER    ┆              ┆ None               │
# │                  ┆                  ┆ COMPLICATIONS  ┆              ┆              ┆                    │
# │ 0e70cf4d3103bc9c ┆ 7bc1502ac99488aa ┆ AN AQI POST-OP ┆ ENCOUNTER    ┆              ┆ None               │
# │                  ┆                  ┆ COMPLICATIONS  ┆              ┆              ┆                    │
# └──────────────────┴──────────────────┴────────────────┴──────────────┴──────────────┴────────────────────┘

# %%
for col in cols_to_encode:
    data, patient_post_op_encoding[col] = encode_column_and_replace(data,col)

# %%
data.head()
# Out:
# shape: (5, 9)
# ┌──────────────┬──────────────┬──────────────┬─────────────┬───┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ LOG_ID       ┆ MRN          ┆ Element_Name ┆ CONTEXT_NAM ┆ … ┆ SMRTDTA_ELE ┆ CONTEXT_NAM ┆ Element_abb ┆ SMRTDTA_ELE │
# │ ---          ┆ ---          ┆ ---          ┆ E           ┆   ┆ M_VALUE     ┆ E_encoded   ┆ r_encoded   ┆ M_VALUE_enc │
# │ str          ┆ str          ┆ str          ┆ ---         ┆   ┆ ---         ┆ ---         ┆ ---         ┆ oded        │
# │              ┆              ┆              ┆ str         ┆   ┆ str         ┆ u64         ┆ u64         ┆ ---         │
# │              ┆              ┆              ┆             ┆   ┆             ┆             ┆             ┆ u64         │
# ╞══════════════╪══════════════╪══════════════╪═════════════╪═══╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ f730e5212222 ┆ 2c8c2d76b0ae ┆ AN AQI       ┆ ENCOUNTER   ┆ … ┆ None        ┆ 0           ┆ 0           ┆ 409         │
# │ 98ed         ┆ 346a         ┆ POST-OP COMP ┆             ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆ LICATIONS    ┆             ┆   ┆             ┆             ┆             ┆             │
# │ fc53c06ee2cf ┆ b7a91e623d95 ┆ AN AQI       ┆ ENCOUNTER   ┆ … ┆ None        ┆ 0           ┆ 0           ┆ 409         │
# │ e438         ┆ 7d8f         ┆ POST-OP COMP ┆             ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆ LICATIONS    ┆             ┆   ┆             ┆             ┆             ┆             │
# │ 8a3336d8a480 ┆ aefa5d48bed8 ┆ AN AQI       ┆ ENCOUNTER   ┆ … ┆ None        ┆ 0           ┆ 0           ┆ 409         │
# │ 2db4         ┆ 6687         ┆ POST-OP COMP ┆             ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆ LICATIONS    ┆             ┆   ┆             ┆             ┆             ┆             │
# │ a99a2b466b58 ┆ 16c69fd7b03e ┆ AN AQI       ┆ ENCOUNTER   ┆ … ┆ None        ┆ 0           ┆ 0           ┆ 409         │
# │ 3603         ┆ 8a31         ┆ POST-OP COMP ┆             ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆ LICATIONS    ┆             ┆   ┆             ┆             ┆             ┆             │
# │ e1a2b6d52dbd ┆ 776fc234d013 ┆ AN AQI       ┆ ENCOUNTER   ┆ … ┆ None        ┆ 0           ┆ 0           ┆ 409         │
# │ 84aa         ┆ 55e4         ┆ POST-OP COMP ┆             ┆   ┆             ┆             ┆             ┆             │
# │              ┆              ┆ LICATIONS    ┆             ┆   ┆             ┆             ┆             ┆             │
# └──────────────┴──────────────┴──────────────┴─────────────┴───┴─────────────┴─────────────┴─────────────┴─────────────┘

# %%
data.null_count()
# Out:
# shape: (1, 9)
# ┌────────┬─────┬──────────────┬──────────────┬───┬─────────────────┬─────────────────┬────────────────┬────────────────┐
# │ LOG_ID ┆ MRN ┆ Element_Name ┆ CONTEXT_NAME ┆ … ┆ SMRTDTA_ELEM_VA ┆ CONTEXT_NAME_en ┆ Element_abbr_e ┆ SMRTDTA_ELEM_V │
# │ ---    ┆ --- ┆ ---          ┆ ---          ┆   ┆ LUE             ┆ coded           ┆ ncoded         ┆ ALUE_encoded   │
# │ u32    ┆ u32 ┆ u32          ┆ u32          ┆   ┆ ---             ┆ ---             ┆ ---            ┆ ---            │
# │        ┆     ┆              ┆              ┆   ┆ u32             ┆ u32             ┆ u32            ┆ u32            │
# ╞════════╪═════╪══════════════╪══════════════╪═══╪═════════════════╪═════════════════╪════════════════╪════════════════╡
# │ 0      ┆ 0   ┆ 0            ┆ 0            ┆ … ┆ 483             ┆ 0               ┆ 0              ┆ 0              │
# └────────┴─────┴──────────────┴──────────────┴───┴─────────────────┴─────────────────┴────────────────┴────────────────┘

# %%
columns_needed = ['SMRTDTA_ELEM_VALUE_encoded','Element_abbr_encoded','CONTEXT_NAME_encoded','LOG_ID','MRN']
data = data.select(columns_needed)
print(data.shape)
data.write_csv('EPIC_EMR_cleaned/patient_post_op_complication_cleaned.csv')
# Out:
# (84950, 5)

# %% [markdown]
# # Cleaning Patient Vist
# This dataset contains the diagnosis information of all visits of patients

# %%
patient_visit_encoding = {}
cols_to_encode = ['dx_name'] 
data = pl.read_csv('EPIC_EMR/patient_visit.csv',dtypes={'diagnosis_code':pl.Utf8})
data = data.unique()

# %%
data.head()
# Out:
# shape: (5, 4)
# ┌──────────────────┬──────────────────┬────────────────┬───────────────────────────────────┐
# │ LOG_ID           ┆ mrn              ┆ diagnosis_code ┆ dx_name                           │
# │ ---              ┆ ---              ┆ ---            ┆ ---                               │
# │ str              ┆ str              ┆ str            ┆ str                               │
# ╞══════════════════╪══════════════════╪════════════════╪═══════════════════════════════════╡
# │ fa149b1b36855b20 ┆ ad8291a53a44f099 ┆ 153.3          ┆ Malignant neoplasm of sigmoid co… │
# │ c795ff491aa100a3 ┆ 08cbba27fbc9ab54 ┆ 153.3          ┆ Malignant neoplasm of sigmoid co… │
# │ 3b76e2436501475d ┆ 2f74e339dfef02a0 ┆ 153.3          ┆ Malignant neoplasm of sigmoid co… │
# │ 883661fd7d8695a2 ┆ b04f771d4c3590bd ┆ 160.0          ┆ Malignant neoplasm of nasal cavi… │
# │ 1d164b42259924a9 ┆ a07eea403d5462f8 ┆ 188.0          ┆ Malignant neoplasm of trigone of… │
# └──────────────────┴──────────────────┴────────────────┴───────────────────────────────────┘

# %%
patient_visit_encoding['dx_name___diagnosis_code'] = encode_two_columns(data,'dx_name','diagnosis_code')
for col in cols_to_encode:
    data, patient_visit_encoding[col] = encode_column_and_replace(data,col)

# %%
data.head()
# Out:
# shape: (5, 5)
# ┌──────────────────┬──────────────────┬────────────────┬─────────────────────────┬─────────────────┐
# │ LOG_ID           ┆ mrn              ┆ diagnosis_code ┆ dx_name                 ┆ dx_name_encoded │
# │ ---              ┆ ---              ┆ ---            ┆ ---                     ┆ ---             │
# │ str              ┆ str              ┆ str            ┆ str                     ┆ u64             │
# ╞══════════════════╪══════════════════╪════════════════╪═════════════════════════╪═════════════════╡
# │ fa149b1b36855b20 ┆ ad8291a53a44f099 ┆ 153.3          ┆ Malignant neoplasm of   ┆ 2139            │
# │                  ┆                  ┆                ┆ sigmoid co…             ┆                 │
# │ c795ff491aa100a3 ┆ 08cbba27fbc9ab54 ┆ 153.3          ┆ Malignant neoplasm of   ┆ 2139            │
# │                  ┆                  ┆                ┆ sigmoid co…             ┆                 │
# │ 3b76e2436501475d ┆ 2f74e339dfef02a0 ┆ 153.3          ┆ Malignant neoplasm of   ┆ 2139            │
# │                  ┆                  ┆                ┆ sigmoid co…             ┆                 │
# │ 883661fd7d8695a2 ┆ b04f771d4c3590bd ┆ 160.0          ┆ Malignant neoplasm of   ┆ 6812            │
# │                  ┆                  ┆                ┆ nasal cavi…             ┆                 │
# │ 1d164b42259924a9 ┆ a07eea403d5462f8 ┆ 188.0          ┆ Malignant neoplasm of   ┆ 25220           │
# │                  ┆                  ┆                ┆ trigone of…             ┆                 │
# └──────────────────┴──────────────────┴────────────────┴─────────────────────────┴─────────────────┘

# %%
data.null_count()
# Out:
# shape: (1, 5)
# ┌────────┬─────┬────────────────┬─────────┬─────────────────┐
# │ LOG_ID ┆ mrn ┆ diagnosis_code ┆ dx_name ┆ dx_name_encoded │
# │ ---    ┆ --- ┆ ---            ┆ ---     ┆ ---             │
# │ u32    ┆ u32 ┆ u32            ┆ u32     ┆ u32             │
# ╞════════╪═════╪════════════════╪═════════╪═════════════════╡
# │ 0      ┆ 0   ┆ 38138          ┆ 0       ┆ 0               │
# └────────┴─────┴────────────────┴─────────┴─────────────────┘

# %%
data = data.select(pl.col('LOG_ID'),pl.col('mrn').alias('MRN'),pl.col('dx_name_encoded'))

# %%
data.shape
# Out:
# (131455, 3)

# %%
data.write_csv('EPIC_EMR_cleaned/patient_visit_cleaned.csv')

# %% [markdown]
# # Cleaning patient procedure events

# %%
patient_procedure_event_encoding = {}
cols_to_encode = ['EVENT_DISPLAY_NAME'] 
data = pl.read_csv('EPIC_EMR/patient_procedure events.csv')
data = data.unique()

# %%
data.head()
# Out:
# shape: (5, 5)
# ┌──────────────────┬──────────────────┬───────────────────────────────┬───────────────┬───────────┐
# │ LOG_ID           ┆ MRN              ┆ EVENT_DISPLAY_NAME            ┆ EVENT_TIME    ┆ NOTE_TEXT │
# │ ---              ┆ ---              ┆ ---                           ┆ ---           ┆ ---       │
# │ str              ┆ str              ┆ str                           ┆ str           ┆ str       │
# ╞══════════════════╪══════════════════╪═══════════════════════════════╪═══════════════╪═══════════╡
# │ fb943d65e18f9037 ┆ 5b63201d6d190849 ┆ TEE Echo Placed               ┆ 9/27/19 7:50  ┆ null      │
# │ 1448853f211a1d17 ┆ 77bb0379da107da0 ┆ Sign In                       ┆ 1/10/19 7:43  ┆ null      │
# │ a51b5cb848f34fd6 ┆ 482f098c5a1eb634 ┆ Quick Note                    ┆ 10/19/19 8:46 ┆ null      │
# │ 068b548cf0d91976 ┆ 68d58e4c2dcd06f6 ┆ Two Anti-Emetics Administered ┆ 5/6/19 12:01  ┆ null      │
# │ fb943d65e18f9037 ┆ 5b63201d6d190849 ┆ Quick Note                    ┆ 9/27/19 13:43 ┆ null      │
# └──────────────────┴──────────────────┴───────────────────────────────┴───────────────┴───────────┘

# %%
for col in cols_to_encode:
    data, patient_procedure_event_encoding[col] = encode_column_and_replace(data,col)

# %%
data.head()
# Out:
# shape: (5, 6)
# ┌─────────────────┬─────────────────┬─────────────────┬───────────────┬───────────┬────────────────┐
# │ LOG_ID          ┆ MRN             ┆ EVENT_DISPLAY_N ┆ EVENT_TIME    ┆ NOTE_TEXT ┆ EVENT_DISPLAY_ │
# │ ---             ┆ ---             ┆ AME             ┆ ---           ┆ ---       ┆ NAME_encoded   │
# │ str             ┆ str             ┆ ---             ┆ str           ┆ str       ┆ ---            │
# │                 ┆                 ┆ str             ┆               ┆           ┆ u64            │
# ╞═════════════════╪═════════════════╪═════════════════╪═══════════════╪═══════════╪════════════════╡
# │ fb943d65e18f903 ┆ 5b63201d6d19084 ┆ TEE Echo Placed ┆ 9/27/19 7:50  ┆ null      ┆ 50             │
# │ 7               ┆ 9               ┆                 ┆               ┆           ┆                │
# │ 1448853f211a1d1 ┆ 77bb0379da107da ┆ Sign In         ┆ 1/10/19 7:43  ┆ null      ┆ 9              │
# │ 7               ┆ 0               ┆                 ┆               ┆           ┆                │
# │ a51b5cb848f34fd ┆ 482f098c5a1eb63 ┆ Quick Note      ┆ 10/19/19 8:46 ┆ null      ┆ 8              │
# │ 6               ┆ 4               ┆                 ┆               ┆           ┆                │
# │ 068b548cf0d9197 ┆ 68d58e4c2dcd06f ┆ Two             ┆ 5/6/19 12:01  ┆ null      ┆ 0              │
# │ 6               ┆ 6               ┆ Anti-Emetics    ┆               ┆           ┆                │
# │                 ┆                 ┆ Administered    ┆               ┆           ┆                │
# │ fb943d65e18f903 ┆ 5b63201d6d19084 ┆ Quick Note      ┆ 9/27/19 13:43 ┆ null      ┆ 8              │
# │ 7               ┆ 9               ┆                 ┆               ┆           ┆                │
# └─────────────────┴─────────────────┴─────────────────┴───────────────┴───────────┴────────────────┘

# %%
data = data.select(['LOG_ID','MRN','EVENT_TIME','EVENT_DISPLAY_NAME_encoded'])

# %%
data.write_csv('EPIC_EMR_cleaned/patient_procedure_events_cleaned.csv')

# %%
patient_procedure_event_encoding
# Out:
# {'EVENT_DISPLAY_NAME': {'Two Anti-Emetics Administered': 0,
#   'Department check-in complete': 1,
#   'Induction': 2,
#   'Admin Review or Deletion': 3,
#   'Start Visit': 4,
#   'IABP Off': 5,
#   'Re Warming': 6,
#   'Mark Now': 7,
#   'Quick Note': 8,
#   'Sign In': 9,
#   'Epidural to C-Section': 10,
#   'Blood Patch Administered': 11,
#   'CV Bypass Initiated': 12,
#   'DHCA Started': 13,
#   'Help Call': 14,
#   'Renal Clamp On': 15,
#   'Patient Moving': 16,
#   'Aortic Clamp Off': 17,
#   'Major Blood Loss': 18,
#   'Start Bedside Data Collection': 19,
#   'Renal Clamp Off': 20,
#   'Visit Complete': 21,
#   'Antibiotics Given': 22,
#   'DHCA Ended': 23,
#   'CPR': 24,
#   'OB Face Time Stop': 25,
#   'Case Delayed': 26,
#   'IABP On': 27,
#   'Carotid Clamp On': 28,
#   'Out Of OR Recovery': 29,
#   'Start Data Collection': 30,
#   'Narcotic Balance': 31,
#   'Aortic Clamp On': 32,
#   'Start Rooming': 33,
#   'IV Antibiotics': 34,
#   'Mask Emergence': 35,
#   'Aortic Cannula': 36,
#   'OB Face Time Start': 37,
#   'LMA Removed': 38,
#   'Venous Cannula': 39,
#   'CV Bypass Ended': 40,
#   'ECT Start': 41,
#   'Follow-up Complete': 42,
#   'Start Cooling': 43,
#   'Uterine Incision': 44,
#   'Pringle On': 45,
#   'OB Delivery Time': 46,
#   'Transported to PACU/ICU with O2, vital signs stable': 47,
#   'Carotid Clamp Off': 48,
#   'Double Lumen Tube Confirmation': 49,
#   'TEE Echo Placed': 50,
#   'On Scheduled IV Abx or IV Abx Not Requested': 51,
#   'Anesthesia Ready': 52,
#   'Mark for Deletion': 53,
#   'ECT Emergence': 54,
#   'Block Request removed': 55,
#   'Anesthesia Start': 56,
#   'Stop Data Collection': 57,
#   'BLOCK REQUESTED': 58,
#   'Case Completion': 59,
#   'Visit Signed': 60,
#   'Data Artifact': 61,
#   'Mark for Admin Review': 62,
#   'Tourniquet Deflated': 63,
#   'OB Infusion': 64,
#   'Surgeon on Cuff': 65,
#   'Skin Incision': 66,
#   'Mask Induction': 67,
#   'One-Lung Ventilation': 68,
#   'ECT Mask Ventilation': 69,
#   'Intubation': 70,
#   'Tourniquet Inflated': 71,
#   'LMA  Placed': 72,
#   'OB Follow-up': 73,
#   'Emergence': 74,
#   'Defibrillation': 75,
#   'Fiberoptic Bronchoscopy': 76,
#   'OB Catheter Removal': 77,
#   'PACU Hold': 78,
#   'In OR Recovery': 79,
#   'Pringle Off': 80,
#   'Stop Bedside Data Collection': 81,
#   'Anesthesia Stop': 82,
#   'Extubation': 83,
#   'Done Rooming': 84,
#   'Block administered': 85,
#   'Two-Lung Ventilation': 86,
#   'Oxytocin Admin': 87,
#   'Case Canceled': 88,
#   'MAC Initiation': 89}}

# %% [markdown]
# Combine all the encoded data from each dataset and store it in json file, inorder to access the actual value of each encoded value

# %%
encoding_dict = {}
encoding_dict['patient_history'] = patient_history_encoding
encoding_dict['patient_information'] = patient_information_encoding
encoding_dict['patient_lab'] = patient_lab_encoding
encoding_dict['patient_post_op_complications'] = patient_post_op_encoding
encoding_dict['patient_visit'] = patient_visit_encoding
encoding_dict['patient_procedure_event'] = patient_procedure_event_encoding

# %%
with open ('EPIC_EMR_cleaned/encoding.json','w') as f:
    json.dump(encoding_dict,f)
